# %% [markdown]
# # Webscrape Example

# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup

# %% [markdown]
# ### Set the URL you want to webscrape from

# %%
url = 'https://timemachinetheband.com/song-list/'

# %% [markdown]
# ### Connect to the URL

# %%
response = requests.get(url)

# %%
response #200 means it went through
# Out:
# <Response [200]>

# %% [markdown]
# ### Parse HTML and save to BeautifulSoup object

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1" name="viewport"/><link href="https://gmpg.org/xfn/11" rel="profile"/><meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"> <!-- This site is optimized with the Yoast SEO plugin v17.0 - https://yoast.com/wordpress/plugins/seo/ --><title>Song List • Time Machine</title><link crossorigin="" href="https://fonts.gstatic.com/" rel="preconnect"><link href="https://fonts.googleapis.com" rel="preconnect"/><style type="text/css">@font-face {
#  font-family: 'Roboto';
#  font-style: italic;
#  font-weight: 100;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOiCnqEu92Fr1Mu51QrEzAdKg.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto';
#  font-style: italic;
#  font-weight: 300;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOjCnqEu92Fr1Mu51TjASc6CsE.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto';
#  font-style: italic;
#  font-weight: 400;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOkCnqEu92Fr1Mu51xIIzc.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto';
#  font-style: italic;
#  font-weight: 500;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOjCnqEu92Fr1Mu51S7ACc6CsE.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto';
#  font-style: italic;
#  font-weight: 700;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOjCnqEu92Fr1Mu51TzBic6CsE.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto';
#  font-style: italic;
#  font-weight: 900;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOjCnqEu92Fr1Mu51TLBCc6CsE.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto';
#  font-style: normal;
#  font-weight: 100;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOkCnqEu92Fr1MmgVxIIzc.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto';
#  font-style: normal;
#  font-weight: 300;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOlCnqEu92Fr1MmSU5fBBc9.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto';
#  font-style: normal;
#  font-weight: 400;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOmCnqEu92Fr1Mu4mxP.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto';
#  font-style: normal;
#  font-weight: 500;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOlCnqEu92Fr1MmEU9fBBc9.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto';
#  font-style: normal;
#  font-weight: 700;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOlCnqEu92Fr1MmWUlfBBc9.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto';
#  font-style: normal;
#  font-weight: 900;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOlCnqEu92Fr1MmYUtfBBc9.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto Slab';
#  font-style: normal;
#  font-weight: 100;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/robotoslab/v13/BngbUXZYTXPIvIBgJJSb6s3BzlRRfKOFbvjojIWmb2Rm.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto Slab';
#  font-style: normal;
#  font-weight: 200;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/robotoslab/v13/BngbUXZYTXPIvIBgJJSb6s3BzlRRfKOFbvjoDISmb2Rm.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto Slab';
#  font-style: normal;
#  font-weight: 300;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/robotoslab/v13/BngbUXZYTXPIvIBgJJSb6s3BzlRRfKOFbvjo0oSmb2Rm.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto Slab';
#  font-style: normal;
#  font-weight: 400;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/robotoslab/v13/BngbUXZYTXPIvIBgJJSb6s3BzlRRfKOFbvjojISmb2Rm.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto Slab';
#  font-style: normal;
#  font-weight: 500;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/robotoslab/v13/BngbUXZYTXPIvIBgJJSb6s3BzlRRfKOFbvjovoSmb2Rm.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto Slab';
#  font-style: normal;
#  font-weight: 600;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/robotoslab/v13/BngbUXZYTXPIvIBgJJSb6s3BzlRRfKOFbvjoUoOmb2Rm.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto Slab';
#  font-style: normal;
#  font-weight: 700;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/robotoslab/v13/BngbUXZYTXPIvIBgJJSb6s3BzlRRfKOFbvjoa4Omb2Rm.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto Slab';
#  font-style: normal;
#  font-weight: 800;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/robotoslab/v13/BngbUXZYTXPIvIBgJJSb6s3BzlRRfKOFbvjoDIOmb2Rm.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto Slab';
#  font-style: normal;
#  font-weight: 900;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/robotoslab/v13/BngbUXZYTXPIvIBgJJSb6s3BzlRRfKOFbvjoJYOmb2Rm.ttf) format('truetype');
# } </style><link href="https://timemachinetheband.com/wp-content/uploads/siteground-optimizer-assets/siteground-optimizer-combined-css-0989f17f4f7a79e49f588e70bf4fcc77.css" id="siteground-optimizer-combined-css-0989f17f4f7a79e49f588e70bf4fcc77" media="all" rel="stylesheet"/><meta content="Search through the Time Machine song list and send us your requests. With over 6 decades worth of music, you're sure to find your favorite song!" name="description"><link href="https://timemachinetheband.com/song-list/" rel="canonical"/><meta content="en_US" property="og:locale"/><meta content="article" property="og:type"/><meta content="Song List • Time Machine" property="og:title"/><meta content="Search through the Time Machine song list and send us your requests. With over 6 decades worth of music, you're sure to find your favorite song!" property="og:description"/><meta content="https://timemachinetheband.com/song-list/" property="og:url"/><meta content="Time Machine" property="og:site_name"/><meta content="2021-05-21T15:59:51+00:00" property="article:modified_time"/><meta content="https://timemachinetheband.com/wp-content/uploads/2020/02/TM-Logo-Featured-Image-Preview.jpg" property="og:image"/><meta content="1200" property="og:image:width"/><meta content="638" property="og:image:height"/><meta content="summary_large_image" name="twitter:card"/><meta content="Est. reading time" name="twitter:label1"/><meta content="24 minutes" name="twitter:data1"/> <script class="yoast-schema-graph" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"Organization","@id":"https://timemachinetheband.com/#organization","name":"Time Machine","url":"https://timemachinetheband.com/","sameAs":[],"logo":{"@type":"ImageObject","@id":"https://timemachinetheband.com/#logo","inLanguage":"en-US","url":"https://timemachinetheband.com/wp-content/uploads/2020/02/Time-Machine-Logo.jpg","contentUrl":"https://timemachinetheband.com/wp-content/uploads/2020/02/Time-Machine-Logo.jpg","width":1200,"height":1200,"caption":"Time Machine"},"image":{"@id":"https://timemachinetheband.com/#logo"}},{"@type":"WebSite","@id":"https://timemachinetheband.com/#website","url":"https://timemachinetheband.com/","name":"Time Machine","description":"Top Cover Band &amp; Live Band Karaoke","publisher":{"@id":"https://timemachinetheband.com/#organization"},"potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://timemachinetheband.com/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"en-US"},{"@type":"ImageObject","@id":"https://timemachinetheband.com/song-list/#primaryimage","inLanguage":"en-US","url":"https://timemachinetheband.com/wp-content/uploads/2020/02/TM-Logo-Featured-Image-Preview.jpg","contentUrl":"https://timemachinetheband.com/wp-content/uploads/2020/02/TM-Logo-Featured-Image-Preview.jpg","width":1200,"height":638,"caption":"Time Machine Top Cover Band & Live Band Karaoke DFW"},{"@type":"WebPage","@id":"https://timemachinetheband.com/song-list/#webpage","url":"https://timemachinetheband.com/song-list/","name":"Song List &bull; Time Machine","isPartOf":{"@id":"https://timemachinetheband.com/#website"},"primaryImageOfPage":{"@id":"https://timemachinetheband.com/song-list/#primaryimage"},"datePublished":"2019-11-28T06:16:50+00:00","dateModified":"2021-05-21T15:59:51+00:00","description":"Search through the Time Machine song list and send us your requests. With over 6 decades worth of music, you're sure to find your favorite song!","breadcrumb":{"@id":"https://timemachinetheband.com/song-list/#breadcrumb"},"inLanguage":"en-US","potentialAction":[{"@type":"ReadAction","target":["https://timemachinetheband.com/song-list/"]}]},{"@type":"BreadcrumbList","@id":"https://timemachinetheband.com/song-list/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":"https://timemachinetheband.com/"},{"@type":"ListItem","position":2,"name":"Song List"}]}]}</script>  ...
#  var em_track_user = true;
#  var em_no_track_reason = '';
#  var disableStr = 'ga-disable-UA-158836598-1';  /* Function to detect opted out users */
#  function __gtagTrackerIsOptedOut() {
#  return document.cookie.indexOf( disableStr + '=true' ) > - 1;
#  }  /* Disable tracking if the opt-out cookie exists. */
#  if ( __gtagTrackerIsOptedOut() ) {
#  window[disableStr] = true;
#  }  /* Opt-out function */
#  function __gtagTrackerOptout() {
#  document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
#  window[disableStr] = true;
#  }  if ( 'undefined' === typeof gaOptout ) {
#  function gaOptout() {
#  __gtagTrackerOptout();
#  }
#  }
#  window.dataLayer = window.dataLayer || [];
#  if ( em_track_user ) {
#  function __gtagTracker() {dataLayer.push( arguments );}
#  __gtagTracker( 'js', new Date() );
#  __gtagTracker( 'set', {
#  'developer_id.dNDMyYj' : true,
#  });
#  __gtagTracker( 'config', 'UA-158836598-1', {
#  forceSSL:true,link_attribution:true,					} );
#  window.gtag = __gtagTracker;										(
#  function () {
#  /* https://developers.google.com/analytics/devguides/collection/analyticsjs/ */
#  /* ga and __gaTracker compatibility shim. */
#  var noopfn = function () {
#  return null;
#  };
#  var newtracker = function () {
#  return new Tracker();
#  };
#  var Tracker = function () {
#  return null;
#  };
#  var p = Tracker.prototype;
#  p.get = noopfn;
#  p.set = noopfn;
#  p.send = function (){
#  var args = Array.prototype.slice.call(arguments);
#  args.unshift( 'send' );
#  __gaTracker.apply(null, args);
#  };
#  var __gaTracker = function () {
#  var len = arguments.length;
#  if ( len === 0 ) {
#  return;
#  }
#  var f = arguments[len - 1];
#  if ( typeof f !== 'object' || f === null || typeof f.hitCallback !== 'function' ) {
#  if ( 'send' === arguments[0] ) {
#  var hitConverted, hitObject = false, action;
#  if ( 'event' === arguments[1] ) {
#  if ( 'undefined' !== typeof arguments[3] ) {
#  hitObject = {
#  'eventAction': arguments[3],
#  'eventCategory': arguments[2],
#  'eventLabel': arguments[4],
#  'value': arguments[5] ? arguments[5] : 1,
#  }
#  }
#  }
#  if ( 'pageview' === arguments[1] ) {
#  if ( 'undefined' !== typeof arguments[2] ) {
#  hitObject = {
#  'eventAction': 'page_view',
#  'page_path' : arguments[2],
#  }
#  }
#  }
#  if ( typeof arguments[2] === 'object' ) {
#  hitObject = arguments[2];
#  }
#  if ( typeof arguments[5] === 'object' ) {
#  Object.assign( hitObject, arguments[5] );
#  }
#  if ( 'undefined' !== typeof arguments[1].hitType ) {
#  hitObject = arguments[1];
#  if ( 'pageview' === hitObject.hitType ) {
#  hitObject.eventAction = 'page_view';
#  }
#  }
#  if ( hitObject ) {
#  action = 'timing' === arguments[1].hitType ? 'timing_complete' : hitObject.eventAction;
#  hitConverted = mapArgs( hitObject );
#  __gtagTracker( 'event', action, hitConverted );
#  }
#  }
#  return;
#  }  function mapArgs( args ) {
#  var arg, hit = {};
#  var gaMap = {
#  'eventCategory': 'event_category',
#  'eventAction': 'event_action',
#  'eventLabel': 'event_label',
#  'eventValue': 'event_value',
#  'nonInteraction': 'non_interaction',
#  'timingCategory': 'event_category',
#  'timingVar': 'name',
#  'timingValue': 'value',
#  'timingLabel': 'event_label',
#  'page' : 'page_path',
#  'location' : 'page_location',
#  'title' : 'page_title',
#  };
#  for ( arg in args ) {
#  if ( args.hasOwnProperty(arg) && gaMap.hasOwnProperty(arg) ) {
#  hit[gaMap[arg]] = args[arg];
#  } else {
#  hit[arg] = args[arg];
#  }
#  }
#  return hit;
#  }  try {
#  f.hitCallback();
#  } catch ( ex ) {
#  }
#  };
#  __gaTracker.create = newtracker;
#  __gaTracker.getByName = newtracker;
#  __gaTracker.getAll = function () {
#  return [];
#  };
#  __gaTracker.remove = noopfn;
#  __gaTracker.loaded = true;
#  window['__gaTracker'] = __gaTracker;
#  }
#  )();
#  } else {
#  console.log( "" );
#  ( function () {
#  function __gtagTracker() {
#  return null;
#  }
#  window['__gtagTracker'] = __gtagTracker;
#  window['gtag'] = __gtagTracker;
#  } )();
#  } </script> <!-- / Google Analytics by ExactMetrics --> <script> window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.1.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.1.0\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/timemachinetheband.com\/wp-includes\/js\/wp-emoji-release.min.js"}};
#  !function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode;p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0);e=i.toDataURL();return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(!p||!p.fillText)return!1;switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])?!1:!s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]);case"emoji":return!s([10084,65039,8205,55357,56613],[10084,65039,8203,55357,56613])}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(n=t.source||{}).concatemoji?c(n.concatemoji):n.wpemoji&&n.twemoji&&(c(n.twemoji),c(n.wpemoji)))}(window,document,window._wpemojiSettings);
#  </script><link href="https://use.typekit.net/pxi6ayr.css" rel="stylesheet" type="text/css"/><style> img.wp-smiley,
# img.emoji {
#  display: inline !important;
#  border: none !important;
#  box-shadow: none !important;
#  height: 1em !important;
#  width: 1em !important;
#  margin: 0 .07em !important;
#  vertical-align: -0.1em !important;
#  background: none !important;
#  padding: 0 !important;
# } </style> <style id="astra-theme-css-inline-css"> html{font-size:100%;}a,.page-title{color:#5015ff;}a:hover,a:focus{color:#7a7a7a;}body,button,input,select,textarea,.ast-button,.ast-custom-button{font-family:-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Oxygen-Sans,Ubuntu,Cantarell,Helvetica Neue,sans-serif;font-weight:300;font-size:16px;font-size:1rem;line-height:1.2;}blockquote{color:#000000;}h1,.entry-content h1,h2,.entry-content h2,h3,.entry-content h3,h4,.entry-content h4,h5,.entry-content h5,h6,.entry-content h6,.site-title,.site-title a{font-weight:normal;}.site-title{font-size:35px;font-size:2.1875rem;display:none;}header .custom-logo-link img{max-width:250px;}.astra-logo-svg{width:250px;}.ast-archive-description .ast-archive-title{font-size:40px;font-size:2.5rem;}.site-header .site-description{font-size:15px;font-size:0.9375rem;display:none;}.entry-title{font-size:30px;font-size:1.875rem;}h1,.entry-content h1{font-size:40px;font-size:2.5rem;}h2,.entry-content h2{font-size:30px;font-size:1.875rem;}h3,.entry-content h3{font-size:25px;font-size:1.5625rem;}h4,.entry-content h4{font-size:20px;font-size:1.25rem;}h5,.entry-content h5{font-size:18px;font-size:1.125rem;}h6,.entry-content h6{font-size:15px;font-size:0.9375rem;}.ast-single-post .entry-title,.page-title{font-size:30px;font-size:1.875rem;}::selection{background-color:#5015ff;color:#ffffff;}body,h1,.entry-title a,.entry-content h1,h2,.entry-content h2,h3,.entry-content h3,h4,.entry-content h4,h5,.entry-content h5,h6,.entry-content h6{color:#393c40;}.tagcloud a:hover,.tagcloud a:focus,.tagcloud a.current-item{color:#ffffff;border-color:#5015ff;background-color:#5015ff;}input:focus,input[type="text"]:focus,input[type="email"]:focus,input[type="url"]:focus,input[type="password"]:focus,input[type="reset"]:focus,input[type="search"]:focus,textarea:focus{border-color:#5015ff;}input[type="radio"]:checked,input[type=reset],input[type="checkbox"]:checked,input[type="checkbox"]:hover:checked,input[type="checkbox"]:focus:checked,input[type=range]::-webkit-slider-thumb{border-color:#5015ff;background-color:#5015ff;box-shadow:none;}.site-footer a:hover + .post-count,.site-footer a:focus + .post-count{background:#5015ff;border-color:#5015ff;}.single .nav-links .nav-previous,.single .nav-links .nav-next{color:#5015ff;}.entry-meta,.entry-meta *{line-height:1.45;color:#5015ff;}.entry-meta a:hover,.entry-meta a:hover *,.entry-meta a:focus,.entry-meta a:focus *,.page-links > .page-link,.page-links .page-link:hover,.post-navigation a:hover{color:#7a7a7a;}.widget-title{font-size:22px;font-size:1.375rem;color:#393c40;}#cat option,.secondary .calendar_wrap thead a,.secondary .calendar_wrap thead a:visited{color:#5015ff;}.secondary .calendar_wrap #today,.ast-progress-val span{background:#5015ff;}.secondary a:hover + .post-count,.secondary a:focus + .post-count{background:#5015ff;border-color:#5015ff;}.calendar_wrap #today > a{color:#ffffff;}.page-links .page-link,.single .post-navigation a{color:#5015ff;}.main-header-menu .menu-link,.ast-header-custom-item a{color:#393c40;}.main-header-menu .menu-item:hover > .menu-link,.main-header-menu .menu-item:hover > .ast-menu-toggle,.main-header-menu .ast-masthead-custom-menu-items a:hover,.main-header-menu .menu-item.focus > .menu-link,.main-header-menu .menu-item.focus > .ast-menu-toggle,.main-header-menu .current-menu-item > .menu-link,.main-header-menu .current-menu-ancestor > .menu-link,.main-header-menu .current-menu-item > .ast-menu-toggle,.main-header-menu .current-menu-ancestor > .ast-menu-toggle{color:#5015ff;}.header-main-layout-3 .ast-main-header-bar-alignment{margin-right:auto;}.header-main-layout-2 .site-header-section-left .ast-site-identity{text-align:left;}.ast-logo-title-inline .site-logo-img{padding-right:1em;}.site-logo-img img{ transition:all 0.2s linear;}.ast-header-break-point .ast-mobile-menu-buttons-minimal.menu-toggle{background:transparent;color:#1e73be;}.ast-header-break-point .ast-mobile-menu-buttons-outline.menu-to ...
#  background-color: #5d4fff;
#  background-image: url(https://timemachinetheband.com/wp-content/plugins/essential-addons-for-elementor-lite/assets/admin/images/templately/logo-icon.svg);
#  background-repeat: no-repeat;
#  background-position: center center;
#  margin-left: 5px;
#  position: relative;
#  bottom: 5px;
#  } </style> <style id="elementor-frontend-inline-css"> @font-face{font-family:eicons;src:url(https://timemachinetheband.com/wp-content/plugins/elementor/assets/lib/eicons/fonts/eicons.eot?5.10.0);src:url(https://timemachinetheband.com/wp-content/plugins/elementor/assets/lib/eicons/fonts/eicons.eot?5.10.0#iefix) format("embedded-opentype"),url(https://timemachinetheband.com/wp-content/plugins/elementor/assets/lib/eicons/fonts/eicons.woff2?5.10.0) format("woff2"),url(https://timemachinetheband.com/wp-content/plugins/elementor/assets/lib/eicons/fonts/eicons.woff?5.10.0) format("woff"),url(https://timemachinetheband.com/wp-content/plugins/elementor/assets/lib/eicons/fonts/eicons.ttf?5.10.0) format("truetype"),url(https://timemachinetheband.com/wp-content/plugins/elementor/assets/lib/eicons/fonts/eicons.svg?5.10.0#eicon) format("svg");font-weight:400;font-style:normal} </style> <script id="jquery-core-js-extra"> var pp = {"ajax_url":"https:\/\/timemachinetheband.com\/wp-admin\/admin-ajax.php"}; </script> <script id="jquery-core-js" src="https://timemachinetheband.com/wp-includes/js/jquery/jquery.min.js"></script> <script defer="" id="jquery-migrate-js" src="https://timemachinetheband.com/wp-includes/js/jquery/jquery-migrate.min.js"></script> <script id="mec-frontend-script-js-extra"> var mecdata = {"day":"day","days":"days","hour":"hour","hours":"hours","minute":"minute","minutes":"minutes","second":"second","seconds":"seconds","elementor_edit_mode":"no","recapcha_key":"","ajax_url":"https:\/\/timemachinetheband.com\/wp-admin\/admin-ajax.php","fes_nonce":"ff5ed6b8cd","current_year":"2021","current_month":"08","datepicker_format":"mm\/dd\/yy&m\/d\/Y"}; </script> <script defer="" id="mec-frontend-script-js" src="https://timemachinetheband.com/wp-content/uploads/siteground-optimizer-assets/mec-frontend-script.min.js"></script> <script defer="" id="mec-events-script-js" src="https://timemachinetheband.com/wp-content/uploads/siteground-optimizer-assets/mec-events-script.min.js"></script> <!--[if IE]> <script defer src='https://timemachinetheband.com/wp-content/themes/astra/assets/js/minified/flexibility.min.js' id='astra-flexibility-js'></script> <script defer id='astra-flexibility-js-after'> flexibility(document.documentElement); </script> <![endif]--> <script id="exactmetrics-frontend-script-js-extra"> var exactmetrics_frontend = {"js_events_tracking":"true","download_extensions":"doc,pdf,ppt,zip,xls,docx,pptx,xlsx","inbound_paths":"[{\"path\":\"\\\/go\\\/\",\"label\":\"affiliate\"},{\"path\":\"\\\/recommend\\\/\",\"label\":\"affiliate\"}]","home_url":"https:\/\/timemachinetheband.com","hash_tracking":"false","ua":"UA-158836598-1"}; </script> <script defer="" id="exactmetrics-frontend-script-js" src="https://timemachinetheband.com/wp-content/plugins/google-analytics-dashboard-for-wp/assets/js/frontend-gtag.min.js"></script> <script defer="" id="font-awesome-4-shim-js" src="https://timemachinetheband.com/wp-content/plugins/elementor/assets/lib/font-awesome/js/v4-shims.min.js"></script><link href="https://timemachinetheband.com/wp-json/" rel="https://api.w.org/"><link href="https://timemachinetheband.com/wp-json/wp/v2/pages/106" rel="alternate" type="application/json"/><link href="https://timemachinetheband.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/><link href="https://timemachinetheband.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/><meta content="WordPress 5.8" name="generator"/><link href="https://timemachinetheband.com/?p=106" rel="shortlink"/><link href="https://timemachinetheband.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Ftimemachinetheband.com%2Fsong-list%2F" rel="alternate" type="application/json+oembed"/><link href="https://timemachinetheband.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Ftimemachinetheband.com%2Fsong-list%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/> <style>.recentcomments a{display:inline !important;padding:0 !important;m ...
# .envato-kit-69-slide-btn .elementor-button,
# .envato-kit-69-cta-btn .elementor-button,
# .envato-kit-69-flip-btn .elementor-button{
#  border-left: 0px !important;
#  border-bottom: 0px !important;
#  border-right: 0px !important;
#  padding: 15px 0 0 !important;
# }
# .envato-kit-69-slide-btn .elementor-slide-button:hover,
# .envato-kit-69-cta-btn .elementor-button:hover,
# .envato-kit-69-flip-btn .elementor-button:hover{
#  margin-bottom: 20px;
# }
# .envato-kit-69-menu .elementor-nav-menu--main a:hover{
#  margin-top: -7px;
#  padding-top: 4px;
#  border-bottom: 1px solid #FFF;
# }
# /* Fix menu dropdown width */
# .envato-kit-69-menu .elementor-nav-menu--dropdown{
#  width: 100% !important;
# }  /** End Envato Elements CSS: Blocks (72-3-34d2cc762876498c8f6be5405a48e6e2) **/  /** Start Envato Elements CSS: Studio (188-3-56c872b7a758ccaa74c4d09a4e253f04) **/  /* envato Custom Styles for Elementor */
# /* colorize carousel */
# .envato-kit-192-carousel-fade .swiper-container{
#  margin:0;
# }
# .envato-kit-192-carousel-fade .slick-slide-image,
# .envato-kit-192-media-carousel .elementor-carousel-image{
#  filter: grayscale(100%) !important;
#  opacity: .8;  }
# .envato-kit-192-media-carousel .elementor-carousel-image{
#  background-color: #d8c3a5;
# }
# .envato-kit-192-media-carousel .elementor-swiper-button-prev{
#  margin-left: -40px;  }
# .envato-kit-192-media-carousel .elementor-custom-embed-play i{
#  background: #FFF;
#  opacity: 1;
#  border-radius: 100%;
# }  /** End Envato Elements CSS: Studio (188-3-56c872b7a758ccaa74c4d09a4e253f04) **/  html,
# body{
# width:100%;
# overflow-x:hidden;
# } </style> <style type="text/css">.mec-hourly-schedule-speaker-name, .mec-events-meta-group-countdown .countdown-w span, .mec-single-event .mec-event-meta dt, .mec-hourly-schedule-speaker-job-title, .post-type-archive-mec-events h1, .mec-ticket-available-spots .mec-event-ticket-name, .tax-mec_category h1, .mec-wrap h1, .mec-wrap h2, .mec-wrap h3, .mec-wrap h4, .mec-wrap h5, .mec-wrap h6,.entry-content .mec-wrap h1, .entry-content .mec-wrap h2, .entry-content .mec-wrap h3,.entry-content  .mec-wrap h4, .entry-content .mec-wrap h5, .entry-content .mec-wrap h6{ font-family: 'Fira Sans', Helvetica, Arial, sans-serif;}.mec-single-event .mec-event-meta .mec-events-event-cost, .mec-event-data-fields .mec-event-data-field-item .mec-event-data-field-value, .mec-event-data-fields .mec-event-data-field-item .mec-event-data-field-name, .mec-wrap .info-msg div, .mec-wrap .mec-error div, .mec-wrap .mec-success div, .mec-wrap .warning-msg div, .mec-breadcrumbs .mec-current, .mec-events-meta-group-tags, .mec-single-event .mec-events-meta-group-booking .mec-event-ticket-available, .mec-single-modern .mec-single-event-bar>div dd, .mec-single-event .mec-event-meta dd, .mec-single-event .mec-event-meta dd a, .mec-next-occ-booking span, .mec-hourly-schedule-speaker-description, .mec-single-event .mec-speakers-details ul li .mec-speaker-job-title, .mec-single-event .mec-speakers-details ul li .mec-speaker-name, .mec-event-data-field-items, .mec-load-more-button, .mec-events-meta-group-tags a, .mec-events-button, .mec-wrap abbr, .mec-event-schedule-content dl dt, .mec-breadcrumbs a, .mec-breadcrumbs span .mec-event-content p, .mec-wrap p { font-family: 'Fira Sans',sans-serif; font-weight:300;}.mec-event-grid-minimal .mec-modal-booking-button:hover, .mec-events-timeline-wrap .mec-organizer-item a, .mec-events-timeline-wrap .mec-organizer-item:after, .mec-events-timeline-wrap .mec-shortcode-organizers i, .mec-timeline-event .mec-modal-booking-button, .mec-wrap .mec-map-lightbox-wp.mec-event-list-classic .mec-event-date, .mec-timetable-t2-col .mec-modal-booking-button:hover, .mec-event-container-classic .mec-modal-booking-button:hover, .mec-calendar-events-side .mec-modal-booking-button:hover, .mec-event-grid-yearly  .mec-modal-booking-button, .mec-events-agenda .mec-modal-booking-button, .mec-event-grid-simple .mec-modal-booking-button, .mec-event-list-minimal  .mec-modal-booking-button:hover, .mec-timeline-month-divider,  .mec-wrap.colorskin-custom .mec-totalcal-box .mec-totalcal-view span:hover,.mec-wrap.colorskin-custom .mec-calendar.mec-event-calendar-classic .mec-selected-day,.mec-wrap.colorskin-custom .mec-color, .mec-wrap.colorskin-custom .mec-event-sharing-wrap .mec-event-sharing > li:hover a, .mec-wrap.colorskin-custom .mec-color-hover:hover, .mec-wrap.colorskin-custom .mec-color-before *:before ,.mec-wrap.colorskin-custom .mec-widget .mec-event-grid-classic.owl-carousel .owl-nav i,.mec-wrap.colorskin-custom .mec-event-list-classic a.magicmore:hover,.mec-wrap.colorskin-custom .mec-event-grid-simple:hover .mec-event-title,.mec-wrap.colorskin-custom .mec-single-event .mec-event-meta dd.mec-events-event-categories:before,.mec-wrap.colorskin-custom .mec-single-event-date:before,.mec-wrap.colorskin-custom .mec-single-event-time:before,.mec-wrap.colorskin-custom .mec-events-meta-group.mec-events-meta-group-venue:before,.mec-wrap.colorskin-custom .mec-calendar .mec-calendar-side .mec-previous-month i,.mec-wrap.colorskin-custom .mec-calendar .mec-calendar-side .mec-next-month:hover,.mec-wrap.colorskin-custom .mec-calendar .mec-calendar-side .mec-previous-month:hover,.mec-wrap.colorskin-custom .mec-calendar .mec-calendar-side .mec-next-month:hover,.mec-wrap.colorskin-custom .mec-calendar.mec-event-calendar-classic dt.mec-selected-day:hover,.mec-wrap.colorskin-custom .mec-infowindow-wp h5 a:hover, .colorskin-custom .mec-events-meta-group-countdown .mec-end-counts h3,.mec-calendar .mec-calendar-side .mec-next-month i,.mec-wrap .mec-totalcal-box i,.mec-ca ...

# %% [markdown]
# ### pretify

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://gmpg.org/xfn/11" rel="profile"/>
#   <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
#    <!-- This site is optimized with the Yoast SEO plugin v17.0 - https://yoast.com/wordpress/plugins/seo/ -->
#    <title>
#     Song List • Time Machine
#    </title>
#    <link crossorigin="" href="https://fonts.gstatic.com/" rel="preconnect">
#     <link href="https://fonts.googleapis.com" rel="preconnect"/>
#     <style type="text/css">
#      @font-face {
#  font-family: 'Roboto';
#  font-style: italic;
#  font-weight: 100;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOiCnqEu92Fr1Mu51QrEzAdKg.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto';
#  font-style: italic;
#  font-weight: 300;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOjCnqEu92Fr1Mu51TjASc6CsE.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto';
#  font-style: italic;
#  font-weight: 400;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOkCnqEu92Fr1Mu51xIIzc.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto';
#  font-style: italic;
#  font-weight: 500;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOjCnqEu92Fr1Mu51S7ACc6CsE.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto';
#  font-style: italic;
#  font-weight: 700;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOjCnqEu92Fr1Mu51TzBic6CsE.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto';
#  font-style: italic;
#  font-weight: 900;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOjCnqEu92Fr1Mu51TLBCc6CsE.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto';
#  font-style: normal;
#  font-weight: 100;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOkCnqEu92Fr1MmgVxIIzc.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto';
#  font-style: normal;
#  font-weight: 300;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOlCnqEu92Fr1MmSU5fBBc9.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto';
#  font-style: normal;
#  font-weight: 400;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOmCnqEu92Fr1Mu4mxP.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto';
#  font-style: normal;
#  font-weight: 500;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOlCnqEu92Fr1MmEU9fBBc9.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto';
#  font-style: normal;
#  font-weight: 700;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOlCnqEu92Fr1MmWUlfBBc9.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto';
#  font-style: normal;
#  font-weight: 900;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/roboto/v27/KFOlCnqEu92Fr1MmYUtfBBc9.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto Slab';
#  font-style: normal;
#  font-weight: 100;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/robotoslab/v13/BngbUXZYTXPIvIBgJJSb6s3BzlRRfKOFbvjojIWmb2Rm.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto Slab';
#  font-style: normal;
#  font-weight: 200;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/robotoslab/v13/BngbUXZYTXPIvIBgJJSb6s3BzlRRfKOFbvjoDISmb2Rm.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto Slab';
#  font-style: normal;
#  font-weight: 300;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/robotoslab/v13/BngbUXZYTXPIvIBgJJSb6s3BzlRRfKOFbvjo0oSmb2Rm.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto Slab';
#  font-style: normal;
#  font-weight: 400;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/robotoslab/v13/BngbUXZYTXPIvIBgJJSb6s3BzlRRfKOFbvjojISmb2Rm.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto Slab';
#  font-style: normal;
#  font-weight: 500;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/robotoslab/v13/BngbUXZYTXPIvIBgJJSb6s3BzlRRfKOFbvjovoSmb2Rm.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto Slab';
#  font-style: normal;
#  font-weight: 600;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/robotoslab/v13/BngbUXZYTXPIvIBgJJSb6s3BzlRRfKOFbvjoUoOmb2Rm.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto Slab';
#  font-style: normal;
#  font-weight: 700;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/robotoslab/v13/BngbUXZYTXPIvIBgJJSb6s3BzlRRfKOFbvjoa4Omb2Rm.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto Slab';
#  font-style: normal;
#  font-weight: 800;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/robotoslab/v13/BngbUXZYTXPIvIBgJJSb6s3BzlRRfKOFbvjoDIOmb2Rm.ttf) format('truetype');
# }
# @font-face {
#  font-family: 'Roboto Slab';
#  font-style: normal;
#  font-weight: 900;
#  font-display: swap;
#  src: url(https://fonts.gstatic.com/s/robotoslab/v13/BngbUXZYTXPIvIBgJJSb6s3BzlRRfKOFbvjoJYOmb2Rm.ttf) format('truetype');
# }
#     </style>
#     <link href="https://timemachinetheband.com/wp-content/uploads/siteground-optimizer-assets/siteground-optimizer-combined-css-0989f17f4f7a79e49f588e70bf4fcc77.css" id="siteground-optimizer-combined-css-0989f17f4f7a79e49f588e70bf4fcc77" media="all" rel="stylesheet"/>
#     <meta content="Search through the Time Machine song list and send us your requests. With over 6 decades worth of music, you're sure to find your favorite song!" name="description">
#      <link href="https://timemachinetheband.com/song-list/" rel="canonical"/>
#      <meta content="en_US" property="og:locale"/>
#      <meta content="article" property="og:type"/>
#      <meta content="Song List • Time Machine" property="og:title"/>
#      <meta content="Search through the Time Machine song list and send us your requests. With over 6 decades worth of music, you're sure to find your favorite song!" property="og:description"/>
#      <meta content="https://timemachinetheband.com/song-list/" property="og:url"/>
#      <meta content="Time Machine" property="og:site_name"/>
#      <meta content="2021-05-21T15:59:51+00:00" property="article:modified_time"/>
#      <meta content="https://timemachinetheband.com/wp-content/uploads/2020/02/TM-Logo-Featured-Image-Preview.jpg" property="og:image"/>
#      <meta content="1200" property="og:image:width"/>
#      <meta content="638" property="og:image:height"/>
#      <meta content="summary_large_image" name="twitter:card"/>
#      <meta content="Est. reading time" name="twitter:label1"/>
#      <meta content="24 minutes" name="twitter:data1"/>
#      <script class="yoast-schema-graph" type="application/ld+json">
#       {"@context":"https://schema.org","@graph":[{"@type":"Organization","@id":"https://timemachinetheband.com/#organization","name":"Time Machine","url":"https://timemachinetheband.com/","sameAs":[],"logo":{"@type":"ImageObject","@id":"https://timemachinetheband.com/#logo","inLanguage":"en-US","url":"https://timemachinetheband.com/wp-content/uploads/2020/02/Time-Machine-Logo.jpg","contentUrl":"https://timemachinetheband.com/wp-content/uploads/2020/02/Time-Machine-Logo.jpg","width":1200,"height":1200,"caption":"Time Machine"},"image":{"@id":"https://timemachinetheband.com/#logo"}},{"@type":"WebSite","@id":"https://timemachinetheband.com/#website","url":"https://timemachinetheband.com/","name":"Time Machine","description":"Top Cover Band &amp; Live Band Karaoke","publisher":{"@id":"https://timemachinetheband.com/#organization"},"potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://timemachinetheband.com/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"en-US"},{"@type":"ImageObject","@id":"https://timemachinetheband.com/song-list/#primaryimage","inLanguage":"en-US","url":"https://timemachinetheband.com/wp-content/uploads/2020/02/TM-Logo-Featured-Image-Preview.jpg","contentUrl":"https://timemachinetheband.com/wp-content/uploads/2020/02/TM-Logo-Featured-Image-Preview.jpg","width":1200,"height":638,"caption":"Time Machine Top Cover Band & Live Band Karaoke DFW"},{"@type":"WebPage","@id":"https://timemachinetheband.com/song-list/#webpage","url":"https://timemachinetheband.com/song-list/","name":"Song List &bull; Time Machine","isPartOf":{"@id":"https://timemachinetheband.com/#website"},"primaryImageOfPage":{"@id":"https://timemachinetheband.com/song-list/#primaryimage"},"datePublished":"2019-11-28T06:16:50+00:00","dateModified":"2021-05-21T15:59:51+00:00","description":"Search through the Time Machine song list and send us your requests. With over 6 decades worth of music, you're sure to find your favorite song!","breadcrumb":{"@id":"https://timemachinetheband.com/song-list/#breadcrumb"},"inLanguage":"en-US","potentialAction":[{"@type":"ReadAction","target":["https://timemachinetheband.com/song-list/"]}]},{"@type":"BreadcrumbList","@id":"https://timemachinetheband.com/song-list/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":"https://timemachinetheband.com/"},{"@type":"ListItem","position":2,"name":"Song List"}]}]}
#      </script>
#      <!-- / Yoast SEO plugin. -->
#      <link href="//s.w.org" rel="dns-prefetch"/>
#      <link href="https://timemachinetheband.com/feed/" rel="alternate" title="Time Machine » Feed" type="application/rss+xml"/>
#      <link href="https://timemachinetheband.com/comments/feed/" rel="alternate" title="Time Machine » Comments Feed" type="application/rss+xml"/>
#      <!-- This site uses the Google Analytics by ExactMetrics plugin v6.8.0 - Using Analytics tracking - https://www.exactmetrics.com/ -->
#      <script async="" data-cfasync="false" src="//www.googletagmanager.com/gtag/js?id=UA-158836598-1" type="text/javascript">
#      </script>
#      <script data-cfasync="false" type="text/javascript">
#       var em_version = '6.8.0';
#  var em_track_user = true;
#  var em_no_track_reason = '';
#  var disableStr = 'ga-disable-UA-158836598-1';  /* Function to detect opted out users */
#  function __gtagTrackerIsOptedOut() {
#  return document.cookie.indexOf( disableStr + '=true' ) > - 1;
#  }  /* Disable tracking if the opt-out cookie exists. */
#  if ( __gtagTrackerIsOptedOut() ) {
#  window[disableStr] = true;
#  }  /* Opt-out function */
#  function __gtagTrackerOptout() {
#  document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
#  window[disableStr] = true;
#  }  if ( 'undefined' === typeof gaOptout ) {
#  function gaOptout() {
#  __gtagTrackerOptout();
#  }
#  }
#  window.dataLayer = window.dataLayer || [];
#  if ( em_track_user ) {
#  function __gtagTracker() {dataLayer.push( arguments );}
#  __gtagTracker( 'js', new Date() );
#  __gtagTracker( 'set', {
#  'developer_id.dNDMyYj' : true,
#  });
#  __gtagTracker( 'config', 'UA-158836598-1', {
#  forceSSL:true,link_attribution:true,					} );
#  window.gtag = __gtagTracker;										(
#  function () {
#  /* https://developers.google.com/analytics/devguides/collection/analyticsjs/ */
#  /* ga and __gaTracker compatibility shim. */
#  var noopfn = function () {
#  return null;
#  };
#  var newtracker = function () {
#  return new Tracker();
#  };
#  var Tracker = function () {
#  return null;
#  };
#  var p = Tracker.prototype;
#  p.get = noopfn;
#  p.set = noopfn;
#  p.send = function (){
#  var args = Array.prototype.slice.call(arguments);
#  args.unshift( 'send' );
#  __gaTracker.apply(null, args);
#  };
#  var __gaTracker = function () {
#  var len = arguments.length;
#  if ( len === 0 ) {
#  return;
#  }
#  var f = arguments[len - 1];
#  if ( typeof f !== 'object' || f === null || typeof f.hitCallback !== 'function' ) {
#  if ( 'send' === arguments[0] ) {
#  var hitConverted, hitObject = false, action;
#  if ( 'event' === arguments[1] ) {
#  if ( 'undefined' !== typeof arguments[3] ) {
#  hitObject = {
#  'eventAction': arguments[3],
#  'eventCategory': arguments[2],
#  'eventLabel': arguments[4],
#  'value': arguments[5] ? arguments[5] : 1,
#  }
#  }
#  }
#  if ( 'pageview' === arguments[1] ) {
#  if ( 'undefined' !== typeof arguments[2] ) {
#  hitObject = {
#  'eventAction': 'page_view',
#  'page_path' : arguments[2],
#  }
#  }
#  }
#  if ( typeof arguments[2] === 'object' ) {
#  hitObject = arguments[2];
#  }
#  if ( typeof arguments[5] === 'object' ) {
#  Object.assign( hitObject, arguments[5] );
#  }
#  if ( 'undefined' !== typeof arguments[1].hitType ) {
#  hitObject = arguments[1];
#  if ( 'pageview' === hitObject.hitType ) {
#  hitObject.eventAction = 'page_view';
#  }
#  }
#  if ( hitObject ) {
#  action = 'timing' === arguments[1].hitType ? 'timing_complete' : hitObject.eventAction;
#  hitConverted = mapArgs( hitObject );
#  __gtagTracker( 'event', action, hitConverted );
#  }
#  }
#  return;
#  }  function mapArgs( args ) {
#  var arg, hit = {};
#  var gaMap = {
#  'eventCategory': 'event_category',
#  'eventAction': 'event_action',
#  'eventLabel': 'event_label',
#  'eventValue': 'event_value',
#  'nonInteraction': 'non_interaction',
#  'timingCategory': 'event_category',
#  'timingVar': 'name',
#  'timingValue': 'value',
#  'timingLabel': 'event_label',
#  'page' : 'page_path',
#  'location' : 'page_location',
#  'title' : 'page_title',
#  };
#  for ( arg in args ) {
#  if ( args.hasOwnProperty(arg) && gaMap.hasOwnProperty(arg) ) {
#  hit[gaMap[arg]] = args[arg];
#  } else {
#  hit[arg] = args[arg];
#  }
#  }
#  return hit;
#  }  try {
#  f.hitCallback();
#  } catch ( ex ) {
#  }
#  };
#  __gaTracker.create = newtracker;
#  __gaTracker.getByName = newtracker;
#  __gaTracker.getAll = function () {
#  return [];
#  };
#  __gaTracker.remove = noopfn;
#  __gaTracker.loaded = true;
#  window['__gaTracker'] = __gaTracker;
#  }
#  )();
#  } else {
#  console.log( "" );
#  ( function () {
#  function __gtagTracker() {
#  return null;
#  }
#  window['__gtagTracker'] = __gtagTracker;
#  window['gtag'] = __gtagTracker;
#  } )();
#  }
#      </script>
#      <!-- / Google Analytics by ExactMetrics -->
#      <script>
#       window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.1.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.1.0\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/timemachinetheband.com\/wp-includes\/js\/wp-emoji-release.min.js"}};
#  !function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode;p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0);e=i.toDataURL();return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(!p||!p.fillText)return!1;switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])?!1:!s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]);case"emoji":return!s([10084,65039,8205,55357,56613],[10084,65039,8203,55357,56613])}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(n=t.source||{}).concatemoji?c(n.concatemoji):n.wpemoji&&n.twemoji&&(c(n.twemoji),c(n.wpemoji)))}(window,document,window._wpemojiSettings);
#      </script>
#      <link href="https://use.typekit.net/pxi6ayr.css" rel="stylesheet" type="text/css"/>
#      <style>
#       img.wp-smiley,
# img.emoji {
#  display: inline !important;
#  border: none !important;
#  box-shadow: none !important;
#  height: 1em !important;
#  width: 1em !important;
#  margin: 0 .07em !important;
#  vertical-align: -0.1em !important;
#  background: none !important;
#  padding: 0 !important;
# }
#      </style>
#      <style id="astra-theme-css-inline-css">
#       html{font-size:100%;}a,.page-title{color:#5015ff;}a:hover,a:focus{color:#7a7a7a;}body,button,input,select,textarea,.ast-button,.ast-custom-button{font-family:-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Oxygen-Sans,Ubuntu,Cantarell,Helvetica Neue,sans-serif;font-weight:300;font-size:16px;font-size:1rem;line-height:1.2;}blockquote{color:#000000;}h1,.entry-content h1,h2,.entry-content h2,h3,.entry-content h3,h4,.entry-content h4,h5,.entry-content h5,h6,.entry-content h6,.site-title,.site-title a{font-weight:normal;}.site-title{font-size:35px;font-size:2.1875rem;display:none;}header .custom-logo-link img{max-width:250px;}.astra-logo-svg{width:250px;}.ast-archive-description .ast-archive-title{font-size:40px;font-size:2.5rem;}.site-header .site-description{font-size:15px;font-size:0.9375rem;display:none;}.entry-title{font-size:30px;font-size:1.875rem;}h1,.entry-content h1{font-size:40px;font-size:2.5rem;}h2,.entry-content h2{font-size:30px;font-size:1.875rem;}h3,.entry-content h3{font-size:25px;font-size:1.5625rem;}h4,.entry-content h4{font-size:20px;font-size:1.25rem;}h5,.entry-content h5{font-size:18px;font-size:1.125rem;}h6,.entry-content h6{font-size:15px;font-size:0.9375rem;}.ast-single-post .entry-title,.page-title{font-size:30px;font-size:1.875rem;}::selection{background-color:#5015ff;color:#ffffff;}body,h1,.entry-title a,.entry-content h1,h2,.entry-content h2,h3,.entry-content h3,h4,.entry-content h4,h5,.entry-content h5,h6,.entry-content h6{color:#393c40;}.tagcloud a:hover,.tagcloud a:focus,.tagcloud a.current-item{color:#ffffff;border-color:#5015ff;background-color:#5015ff;}input:focus,input[type="text"]:focus,input[type="email"]:focus,input[type="url"]:focus,input[type="password"]:focus,input[type="reset"]:focus,input[type="search"]:focus,textarea:focus{border-color:#5015ff;}input[type="radio"]:checked,input[type=reset],input[type="checkbox"]:checked,input[type="checkbox"]:hover:checked,input[type="checkbox"]:focus:checked,input[type=range]::-webkit-slider-thumb{border-color:#5015ff;background-color:#5015ff;box-shadow:none;}.site-footer a:hover + .post-count,.site-footer a:focus + .post-count{background:#5015ff;border-color:#5015ff;}.single .nav-links .nav-previous,.single .nav-links .nav-next{color:#5015ff;}.entry-meta,.entry-meta *{line-height:1.45;color:#5015ff;}.entry-meta a:hover,.entry-meta a:hover *,.entry-meta a:focus,.entry-meta a:focus *,.page-links > .page-link,.page-links .page-link:hover,.post-navigation a:hover{color:#7a7a7a;}.widget-title{font-size:22px;font-size:1.375rem;color:#393c40;}#cat option,.secondary .calendar_wrap thead a,.secondary .calendar_wrap thead a:visited{color:#5015ff;}.secondary .calendar_wrap #today,.ast-progress-val span{background:#5015ff;}.secondary a:hover + .post-count,.secondary a:focus + .post-count{background:#5015ff;border-color:#5015ff;}.calendar_wrap #today > a{color:#ffffff;}.page-links .page-link,.single .post-navigation a{color:#5015ff;}.main-header-menu .menu-link,.ast-header-custom-item a{color:#393c40;}.main-header-menu .menu-item:hover > .menu-link,.main-header-menu .menu-item:hover > .ast-menu-toggle,.main-header-menu .ast-masthead-custom-menu-items a:hover,.main-header-menu .menu-item.focus > .menu-link,.main-header-menu .menu-item.focus > .ast-menu-toggle,.main-header-menu .current-menu-item > .menu-link,.main-header-menu .current-menu-ancestor > .menu-link,.main-header-menu .current-menu-item > .ast-menu-toggle,.main-header-menu .current-menu-ancestor > .ast-menu-toggle{color:#5015ff;}.header-main-layout-3 .ast-main-header-bar-alignment{margin-right:auto;}.header-main-layout-2 .site-header-section-left .ast-site-identity{text-align:left;}.ast-logo-title-inline .site-logo-img{padding-right:1em;}.site-logo-img img{ transition:all 0.2s linear;}.ast-header-break-point .ast-mobile-menu-buttons-minimal.menu-toggle{background:transparent;color:#1e73be;}.ast-header-break-point .ast-mobile-menu-buttons-outline.menu-toggle{background:transparent;border:1px solid  ...
#      </style>
#      <style id="elementor-icons-inline-css">
#       .elementor-add-new-section .elementor-add-templately-promo-button{
#  background-color: #5d4fff;
#  background-image: url(https://timemachinetheband.com/wp-content/plugins/essential-addons-for-elementor-lite/assets/admin/images/templately/logo-icon.svg);
#  background-repeat: no-repeat;
#  background-position: center center;
#  margin-left: 5px;
#  position: relative;
#  bottom: 5px;
#  }
#      </style>
#      <style id="elementor-frontend-inline-css">
#       @font-face{font-family:eicons;src:url(https://timemachinetheband.com/wp-content/plugins/elementor/assets/lib/eicons/fonts/eicons.eot?5.10.0);src:url(https://timemachinetheband.com/wp-content/plugins/elementor/assets/lib/eicons/fonts/eicons.eot?5.10.0#iefix) format("embedded-opentype"),url(https://timemachinetheband.com/wp-content/plugins/elementor/assets/lib/eicons/fonts/eicons.woff2?5.10.0) format("woff2"),url(https://timemachinetheband.com/wp-content/plugins/elementor/assets/lib/eicons/fonts/eicons.woff?5.10.0) format("woff"),url(https://timemachinetheband.com/wp-content/plugins/elementor/assets/lib/eicons/fonts/eicons.ttf?5.10.0) format("truetype"),url(https://timemachinetheband.com/wp-content/plugins/elementor/assets/lib/eicons/fonts/eicons.svg?5.10.0#eicon) format("svg");font-weight:400;font-style:normal}
#      </style>
#      <script id="jquery-core-js-extra">
#       var pp = {"ajax_url":"https:\/\/timemachinetheband.com\/wp-admin\/admin-ajax.php"};
#      </script>
#      <script id="jquery-core-js" src="https://timemachinetheband.com/wp-includes/js/jquery/jquery.min.js">
#      </script>
#      <script defer="" id="jquery-migrate-js" src="https://timemachinetheband.com/wp-includes/js/jquery/jquery-migrate.min.js">
#      </script>
#      <script id="mec-frontend-script-js-extra">
#       var mecdata = {"day":"day","days":"days","hour":"hour","hours":"hours","minute":"minute","minutes":"minutes","second":"second","seconds":"seconds","elementor_edit_mode":"no","recapcha_key":"","ajax_url":"https:\/\/timemachinetheband.com\/wp-admin\/admin-ajax.php","fes_nonce":"ff5ed6b8cd","current_year":"2021","current_month":"08","datepicker_format":"mm\/dd\/yy&m\/d\/Y"};
#      </script>
#      <script defer="" id="mec-frontend-script-js" src="https://timemachinetheband.com/wp-content/uploads/siteground-optimizer-assets/mec-frontend-script.min.js">
#      </script>
#      <script defer="" id="mec-events-script-js" src="https://timemachinetheband.com/wp-content/uploads/siteground-optimizer-assets/mec-events-script.min.js">
#      </script>
#      <!--[if IE]> <script defer src='https://timemachinetheband.com/wp-content/themes/astra/assets/js/minified/flexibility.min.js' id='astra-flexibility-js'></script> <script defer id='astra-flexibility-js-after'> flexibility(document.documentElement); </script> <![endif]-->
#      <script id="exactmetrics-frontend-script-js-extra">
#       var exactmetrics_frontend = {"js_events_tracking":"true","download_extensions":"doc,pdf,ppt,zip,xls,docx,pptx,xlsx","inbound_paths":"[{\"path\":\"\\\/go\\\/\",\"label\":\"affiliate\"},{\"path\":\"\\\/recommend\\\/\",\"label\":\"affiliate\"}]","home_url":"https:\/\/timemachinetheband.com","hash_tracking":"false","ua":"UA-158836598-1"};
#      </script>
#      <script defer="" id="exactmetrics-frontend-script-js" src="https://timemachinetheband.com/wp-content/plugins/google-analytics-dashboard-for-wp/assets/js/frontend-gtag.min.js">
#      </script>
#      <script defer="" id="font-awesome-4-shim-js" src="https://timemachinetheband.com/wp-content/plugins/elementor/assets/lib/font-awesome/js/v4-shims.min.js">
#      </script>
#      <link href="https://timemachinetheband.com/wp-json/" rel="https://api.w.org/">
#       <link href="https://timemachinetheband.com/wp-json/wp/v2/pages/106" rel="alternate" type="application/json"/>
#       <link href="https://timemachinetheband.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
#       <link href="https://timemachinetheband.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
#       <meta content="WordPress 5.8" name="generator"/>
#       <link href="https://timemachinetheband.com/?p=106" rel="shortlink"/>
#       <link href="https://timemachinetheband.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Ftimemachinetheband.com%2Fsong-list%2F" rel="alternate" type="application/json+oembed"/>
#       <link href="https://timemachinetheband.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Ftimemachinetheband.com%2Fsong-list%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
#       <style>
#        .recentcomments a{display:inline !important;padding:0 !important;margin:0 !important;}
#       </style>
#       <link href="https://timemachinetheband.com/wp-content/uploads/2020/02/TM-Logo-Web-Icon.png" rel="icon" sizes="32x32"/>
#       <link href="https://timemachinetheband.com/wp-content/uploads/2020/02/TM-Logo-Web-Icon.png" rel="icon" sizes="192x192"/>
#       <link href="https://timemachinetheband.com/wp-content/uploads/2020/02/TM-Logo-Web-Icon.png" rel="apple-touch-icon"/>
#       <meta content="https://timemachinetheband.com/wp-content/uploads/2020/02/TM-Logo-Web-Icon.png" name="msapplication-TileImage"/>
#       <style id="wp-custom-css">
#        /** Start Envato Elements CSS: Blocks (72-3-34d2cc762876498c8f6be5405a48e6e2) **/  .envato-block__preview{overflow: visible;}  /*Kit 69 Custom Styling for buttons */
# .envato-kit-69-slide-btn .elementor-button,
# .envato-kit-69-cta-btn .elementor-button,
# .envato-kit-69-flip-btn .elementor-button{
#  border-left: 0px !important;
#  border-bottom: 0px !important;
#  border-right: 0px !important;
#  padding: 15px 0 0 !important;
# }
# .envato-kit-69-slide-btn .elementor-slide-button:hover,
# .envato-kit-69-cta-btn .elementor-button:hover,
# .envato-kit-69-flip-btn .elementor-button:hover{
#  margin-bottom: 20px;
# }
# .envato-kit-69-menu .elementor-nav-menu--main a:hover{
#  margin-top: -7px;
#  padding-top: 4px;
#  border-bottom: 1px solid #FFF;
# }
# /* Fix menu dropdown width */
# .envato-kit-69-menu .elementor-nav-menu--dropdown{
#  width: 100% !important;
# }  /** End Envato Elements CSS: Blocks (72-3-34d2cc762876498c8f6be5405a48e6e2) **/  /** Start Envato Elements CSS: Studio (188-3-56c872b7a758ccaa74c4d09a4e253f04) **/  /* envato Custom Styles for Elementor */
# /* colorize carousel */
# .envato-kit-192-carousel-fade .swiper-container{
#  margin:0;
# }
# .envato-kit-192-carousel-fade .slick-slide-image,
# .envato-kit-192-media-carousel .elementor-carousel-image{
#  filter: grayscale(100%) !important;
#  opacity: .8;  }
# .envato-kit-192-media-carousel .elementor-carousel-image{
#  background-color: #d8c3a5;
# }
# .envato-kit-192-media-carousel .elementor-swiper-button-prev{
#  margin-left: -40px;  }
# .envato-kit-192-media-carousel .elementor-custom-embed-play i{
#  background: #FFF;
#  opacity: 1;
#  border-radius: 100%;
# }  /** End Envato Elements CSS: Studio (188-3-56c872b7a758ccaa74c4d09a4e253f04) **/  html,
# body{
# width:100%;
# overflow-x:hidden;
# }
#       </style>
#       <style type="text/css">
#        .mec-hourly-schedule-speaker-name, .mec-events-meta-group-countdown .countdown-w span, .mec-single-event .mec-event-meta dt, .mec-hourly-schedule-speaker-job-title, .post-type-archive-mec-events h1, .mec-ticket-available-spots .mec-event-ticket-name, .tax-mec_category h1, .mec-wrap h1, .mec-wrap h2, .mec-wrap h3, .mec-wrap h4, .mec-wrap h5, .mec-wrap h6,.entry-content .mec-wrap h1, .entry-content .mec-wrap h2, .entry-content .mec-wrap h3,.entry-content  .mec-wrap h4, .entry-content .mec-wrap h5, .entry-content .mec-wrap h6{ font-family: 'Fira Sans', Helvetica, Arial, sans-serif;}.mec-single-event .mec-event-meta .mec-events-event-cost, .mec-event-data-fields .mec-event-data-field-item .mec-event-data-field-value, .mec-event-data-fields .mec-event-data-field-item .mec-event-data-field-name, .mec-wrap .info-msg div, .mec-wrap .mec-error div, .mec-wrap .mec-success div, .mec-wrap .warning-msg div, .mec-breadcrumbs .mec-current, .mec-events-meta-group-tags, .mec-single-event .mec-events-meta-group-booking .mec-event-ticket-available, .mec-single-modern .mec-single-event-bar>div dd, .mec-single-event .mec-event-meta dd, .mec-single-event .mec-event-meta dd a, .mec-next-occ-booking span, .mec-hourly-schedule-speaker-description, .mec-single-event .mec-speakers-details ul li .mec-speaker-job-title, .mec-single-event .mec-speakers-details ul li .mec-speaker-name, .mec-event-data-field-items, .mec-load-more-button, .mec-events-meta-group-tags a, .mec-events-button, .mec-wrap abbr, .mec-event-schedule-content dl dt, .mec-breadcrumbs a, .mec-breadcrumbs span .mec-event-content p, .mec-wrap p { font-family: 'Fira Sans',sans-serif; font-weight:300;}.mec-event-grid-minimal .mec-modal-booking-button:hover, .mec-events-timeline-wrap .mec-organizer-item a, .mec-events-timeline-wrap .mec-organizer-item:after, .mec-events-timeline-wrap .mec-shortcode-organizers i, .mec-timeline-event .mec-modal-booking-button, .mec-wrap .mec-map-lightbox-wp.mec-event-list-classic .mec-event-date, .mec-timetable-t2-col .mec-modal-booking-button:hover, .mec-event-container-classic .mec-modal-booking-button:hover, .mec-calendar-events-side .mec-modal-booking-button:hover, .mec-event-grid-yearly  .mec-modal-booking-button, .mec-events-agenda .mec-modal-booking-button, .mec-event-grid-simple .mec-modal-booking-button, .mec-event-list-minimal  .mec-modal-booking-button:hover, .mec-timeline-month-divider,  .mec-wrap.colorskin-custom .mec-totalcal-box .mec-totalcal-view span:hover,.mec-wrap.colorskin-custom .mec-calendar.mec-event-calendar-classic .mec-selected-day,.mec-wrap.colorskin-custom .mec-color, .mec-wrap.colorskin-custom .mec-event-sharing-wrap .mec-event-sharing > li:hover a, .mec-wrap.colorskin-custom .mec-color-hover:hover, .mec-wrap.colorskin-custom .mec-color-before *:before ,.mec-wrap.colorskin-custom .mec-widget .mec-event-grid-classic.owl-carousel .owl-nav i,.mec-wrap.colorskin-custom .mec-event-list-classic a.magicmore:hover,.mec-wrap.colorskin-custom .mec-event-grid-simple:hover .mec-event-title,.mec-wrap.colorskin-custom .mec-single-event .mec-event-meta dd.mec-events-event-categories:before,.mec-wrap.colorskin-custom .mec-single-event-date:before,.mec-wrap.colorskin-custom .mec-single-event-time:before,.mec-wrap.colorskin-custom .mec-events-meta-group.mec-events-meta-group-venue:before,.mec-wrap.colorskin-custom .mec-calendar .mec-calendar-side .mec-previous-month i,.mec-wrap.colorskin-custom .mec-calendar .mec-calendar-side .mec-next-month:hover,.mec-wrap.colorskin-custom .mec-calendar .mec-calendar-side .mec-previous-month:hover,.mec-wrap.colorskin-custom .mec-calendar .mec-calendar-side .mec-next-month:hover,.mec-wrap.colorskin-custom .mec-calendar.mec-event-calendar-classic dt.mec-selected-day:hover,.mec-wrap.colorskin-custom .mec-infowindow-wp h5 a:hover, .colorskin-custom .mec-events-meta-group-countdown .mec-end-counts h3,.mec-calendar .mec-calendar-side .mec-next-month i,.mec-wrap .mec-totalcal-box i,.mec-calendar .mec-event-article . ...
#       </style>
#      </link>
#     </meta>
#    </link>
#   </meta>
#  </head>
#  <body class="page-template-default page page-id-106 wp-custom-logo ast-desktop ast-page-builder-template ast-no-sidebar astra-3.6.8 ast-header-custom-item-inside ast-single-post ast-inherit-site-logo-transparent ast-theme-transparent-header elementor-default elementor-kit-2163 elementor-page elementor-page-106" itemscope="itemscope" itemtype="https://schema.org/WebPage">
#   <div class="hfeed site" id="page">
#    <a class="skip-link screen-reader-text" href="#content">
#     Skip to content
#    </a>
#    <div class="elementor elementor-222 elementor-location-header" data-elementor-id="222" data-elementor-settings="[]" data-elementor-type="header">
#     <div class="elementor-section-wrap">
#      <section class="elementor-section elementor-top-section elementor-element elementor-element-a3540d8 elementor-section-stretched elementor-section-boxed elementor-section-height-default elementor-section-height-default" data-element_type="section" data-id="a3540d8" data-settings='{"background_background":"classic","stretch_section":"section-stretched"}'>
#       <div class="elementor-container elementor-column-gap-default">
#        <div class="elementor-row">
#         <div class="elementor-column elementor-col-33 elementor-top-column elementor-element elementor-element-e88f11c" data-element_type="column" data-id="e88f11c" data-settings='{"background_background":"classic"}'>
#          <div class="elementor-column-wrap elementor-element-populated">
#           <div class="elementor-widget-wrap">
#            <div class="elementor-element elementor-element-111444e elementor-widget elementor-widget-theme-site-logo elementor-widget-image" data-element_type="widget" data-id="111444e" data-widget_type="theme-site-logo.default">
#             <div class="elementor-widget-container">
#              <div class="elementor-image">
#               <a href="https://timemachinetheband.com">
#                <img alt="" class="attachment-full size-full" height="500" src="https://timemachinetheband.com/wp-content/uploads/2020/01/cropped-Time-Machine_New-Logo-250x245.png" width="511"/>
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="elementor-column elementor-col-100 elementor-top-column elementor-element elementor-element-16916a9" data-element_type="column" data-id="16916a9">
#          <div class="elementor-column-wrap elementor-element-populated">
#           <div class="elementor-widget-wrap">
#            <div class="elementor-element elementor-element-f408d81 elementor-nav-menu__align-right elementor-nav-menu__text-align-center elementor-nav-menu--stretch elementor-nav-menu--dropdown-mobile elementor-hidden-phone elementor-nav-menu--toggle elementor-nav-menu--burger elementor-widget elementor-widget-nav-menu" data-element_type="widget" data-id="f408d81" data-settings='{"full_width":"stretch","submenu_icon":{"value":"&lt;i class=\"\"&gt;&lt;\/i&gt;","library":""},"layout":"horizontal","toggle":"burger"}' data-widget_type="nav-menu.default">
#             <div class="elementor-widget-container">
#              <nav class="elementor-nav-menu--main elementor-nav-menu__container elementor-nav-menu--layout-horizontal e--pointer-text e--animation-none" migrated="0" migration_allowed="1" role="navigation">
#               <ul class="elementor-nav-menu" id="menu-1-f408d81">
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-item-159">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/">
#                  Home
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-162">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/the-band/">
#                  The Band
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-163">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/calendar/">
#                  Calendar
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-106 current_page_item menu-item-113">
#                 <a aria-current="page" class="elementor-item elementor-item-active menu-link" href="https://timemachinetheband.com/song-list/">
#                  Song List
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-166">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/live-band-karaoke/">
#                  Live Band Karaoke
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1432">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/total-request-live/">
#                  Total Request Live
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2027">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/photos/">
#                  Photos
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2187">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/time-machine-epk/">
#                  EPK
#                 </a>
#                </li>
#               </ul>
#              </nav>
#              <div aria-expanded="false" aria-label="Menu Toggle" class="elementor-menu-toggle" role="button" tabindex="0">
#               <i aria-hidden="true" class="eicon-menu-bar" role="presentation">
#               </i>
#               <span class="elementor-screen-only">
#                Menu
#               </span>
#              </div>
#              <nav aria-hidden="true" class="elementor-nav-menu--dropdown elementor-nav-menu__container" role="navigation">
#               <ul class="elementor-nav-menu" id="menu-2-f408d81">
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-item-159">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/" tabindex="-1">
#                  Home
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-162">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/the-band/" tabindex="-1">
#                  The Band
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-163">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/calendar/" tabindex="-1">
#                  Calendar
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-106 current_page_item menu-item-113">
#                 <a aria-current="page" class="elementor-item elementor-item-active menu-link" href="https://timemachinetheband.com/song-list/" tabindex="-1">
#                  Song List
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-166">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/live-band-karaoke/" tabindex="-1">
#                  Live Band Karaoke
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1432">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/total-request-live/" tabindex="-1">
#                  Total Request Live
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2027">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/photos/" tabindex="-1">
#                  Photos
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2187">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/time-machine-epk/" tabindex="-1">
#                  EPK
#                 </a>
#                </li>
#               </ul>
#              </nav>
#             </div>
#            </div>
#            <div class="elementor-element elementor-element-ef9b722 elementor-nav-menu__align-right elementor-nav-menu__text-align-center elementor-nav-menu--stretch elementor-nav-menu--dropdown-mobile elementor-hidden-desktop elementor-hidden-tablet elementor-nav-menu--toggle elementor-nav-menu--burger elementor-widget elementor-widget-nav-menu" data-element_type="widget" data-id="ef9b722" data-settings='{"full_width":"stretch","submenu_icon":{"value":"&lt;i class=\"\"&gt;&lt;\/i&gt;","library":""},"layout":"horizontal","toggle":"burger"}' data-widget_type="nav-menu.default">
#             <div class="elementor-widget-container">
#              <nav class="elementor-nav-menu--main elementor-nav-menu__container elementor-nav-menu--layout-horizontal e--pointer-text e--animation-none" migrated="0" migration_allowed="1" role="navigation">
#               <ul class="elementor-nav-menu" id="menu-1-ef9b722">
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-item-3064">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/">
#                  Home
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3065">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/the-band/">
#                  The Band
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3066">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/calendar/">
#                  Calendar
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-106 current_page_item menu-item-3067">
#                 <a aria-current="page" class="elementor-item elementor-item-active menu-link" href="https://timemachinetheband.com/song-list/">
#                  Song List
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3068">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/live-band-karaoke/">
#                  Live Band Karaoke
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3069">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/total-request-live/">
#                  Total Request Live
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3070">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/photos/">
#                  Photos
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3071">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/time-machine-epk/">
#                  EPK
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3072">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/contact-time-machine/">
#                  Contact
#                 </a>
#                </li>
#               </ul>
#              </nav>
#              <div aria-expanded="false" aria-label="Menu Toggle" class="elementor-menu-toggle" role="button" tabindex="0">
#               <i aria-hidden="true" class="eicon-menu-bar" role="presentation">
#               </i>
#               <span class="elementor-screen-only">
#                Menu
#               </span>
#              </div>
#              <nav aria-hidden="true" class="elementor-nav-menu--dropdown elementor-nav-menu__container" role="navigation">
#               <ul class="elementor-nav-menu" id="menu-2-ef9b722">
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-item-3064">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/" tabindex="-1">
#                  Home
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3065">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/the-band/" tabindex="-1">
#                  The Band
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3066">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/calendar/" tabindex="-1">
#                  Calendar
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-106 current_page_item menu-item-3067">
#                 <a aria-current="page" class="elementor-item elementor-item-active menu-link" href="https://timemachinetheband.com/song-list/" tabindex="-1">
#                  Song List
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3068">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/live-band-karaoke/" tabindex="-1">
#                  Live Band Karaoke
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3069">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/total-request-live/" tabindex="-1">
#                  Total Request Live
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3070">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/photos/" tabindex="-1">
#                  Photos
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3071">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/time-machine-epk/" tabindex="-1">
#                  EPK
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3072">
#                 <a class="elementor-item menu-link" href="https://timemachinetheband.com/contact-time-machine/" tabindex="-1">
#                  Contact
#                 </a>
#                </li>
#               </ul>
#              </nav>
#             </div>
#            </div>
#            <section class="elementor-section elementor-inner-section elementor-element elementor-element-b260173 elementor-hidden-phone elementor-section-boxed elementor-section-height-default elementor-section-height-default" data-element_type="section" data-id="b260173">
#             <div class="elementor-container elementor-column-gap-default">
#              <div class="elementor-row">
#               <div class="elementor-column elementor-col-50 elementor-inner-column elementor-element elementor-element-3f17925" data-element_type="column" data-id="3f17925">
#                <div class="elementor-column-wrap elementor-element-populated">
#                 <div class="elementor-widget-wrap">
#                  <div class="elementor-element elementor-element-93da7cb elementor-shape-circle e-grid-align-mobile-center e-grid-align-right elementor-grid-0 elementor-widget elementor-widget-social-icons" data-element_type="widget" data-id="93da7cb" data-widget_type="social-icons.default">
# ...
#                                 <span class="elementor-button-icon">
#                                 </span>
#                                 <span class="elementor-button-text">
#                                  Send
#                                 </span>
#                                </span>
#                               </button>
#                              </div>
#                             </div>
#                            </input>
#                           </form>
#                          </div>
#                         </div>
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                   </section>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </section>
#            </div>
#           </div>
#          </div>
#         </div>
#         <!-- .entry-content .clear -->
#        </article>
#        <!-- #post-## -->
#       </main>
#       <!-- #main -->
#      </div>
#      <!-- #primary -->
#     </div>
#     <!-- ast-container -->
#    </div>
#    <!-- #content -->
#    <div class="elementor elementor-252 elementor-location-footer" data-elementor-id="252" data-elementor-settings="[]" data-elementor-type="footer">
#     <div class="elementor-section-wrap">
#      <section class="elementor-section elementor-top-section elementor-element elementor-element-3a961204 elementor-section-full_width elementor-section-height-default elementor-section-height-default" data-element_type="section" data-id="3a961204" data-settings='{"background_background":"classic"}'>
#       <div class="elementor-container elementor-column-gap-default">
#        <div class="elementor-row">
#         <div class="elementor-column elementor-col-100 elementor-top-column elementor-element elementor-element-1c389847" data-element_type="column" data-id="1c389847">
#          <div class="elementor-column-wrap elementor-element-populated">
#           <div class="elementor-widget-wrap">
#            <div class="elementor-element elementor-element-81d39bf elementor-shape-circle e-grid-align-mobile-center elementor-hidden-desktop elementor-hidden-tablet elementor-hidden-phone elementor-grid-0 e-grid-align-center elementor-widget elementor-widget-social-icons" data-element_type="widget" data-id="81d39bf" data-widget_type="social-icons.default">
#             <div class="elementor-widget-container">
#              <div class="elementor-social-icons-wrapper elementor-grid">
#               <span class="elementor-grid-item">
#                <a class="elementor-icon elementor-social-icon elementor-social-icon-facebook elementor-repeater-item-9b09ecc" href="https://www.facebook.com/TimeMachineBandDallas" target="_blank">
#                 <span class="elementor-screen-only">
#                  Facebook
#                 </span>
#                 <i class="fab fa-facebook">
#                 </i>
#                </a>
#               </span>
#               <span class="elementor-grid-item">
#                <a class="elementor-icon elementor-social-icon elementor-social-icon-instagram elementor-repeater-item-3785b61" href="https://instagram.com/timemachinetheband/" target="_blank">
#                 <span class="elementor-screen-only">
#                  Instagram
#                 </span>
#                 <i class="fab fa-instagram">
#                 </i>
#                </a>
#               </span>
#               <span class="elementor-grid-item">
#                <a class="elementor-icon elementor-social-icon elementor-social-icon-twitter elementor-repeater-item-b48e0e1" href="https://twitter.com/_time_machine" target="_blank">
#                 <span class="elementor-screen-only">
#                  Twitter
#                 </span>
#                 <i class="fab fa-twitter">
#                 </i>
#                </a>
#               </span>
#              </div>
#             </div>
#            </div>
#            <div class="elementor-element elementor-element-27a202c e-grid-align-mobile-center elementor-shape-rounded elementor-grid-0 e-grid-align-center elementor-widget elementor-widget-social-icons" data-element_type="widget" data-id="27a202c" data-widget_type="social-icons.default">
#             <div class="elementor-widget-container">
#              <div class="elementor-social-icons-wrapper elementor-grid">
#               <span class="elementor-grid-item">
#                <a class="elementor-icon elementor-social-icon elementor-social-icon-facebook elementor-repeater-item-3be9808" href="https://www.facebook.com/TimeMachineBandDallas" target="_blank">
#                 <span class="elementor-screen-only">
#                  Facebook
#                 </span>
#                 <i class="fab fa-facebook">
#                 </i>
#                </a>
#               </span>
#               <span class="elementor-grid-item">
#                <a class="elementor-icon elementor-social-icon elementor-social-icon-instagram elementor-repeater-item-7facef2" href="https://instagram.com/timemachinetheband/" target="_blank">
#                 <span class="elementor-screen-only">
#                  Instagram
#                 </span>
#                 <i class="fab fa-instagram">
#                 </i>
#                </a>
#               </span>
#               <span class="elementor-grid-item">
#                <a class="elementor-icon elementor-social-icon elementor-social-icon-twitter elementor-repeater-item-f96498d" href="https://twitter.com/_time_machine" target="_blank">
#                 <span class="elementor-screen-only">
#                  Twitter
#                 </span>
#                 <i class="fab fa-twitter">
#                 </i>
#                </a>
#               </span>
#              </div>
#             </div>
#            </div>
#            <div class="elementor-element elementor-element-1fb259c elementor-align-center elementor-tablet-align-center elementor-mobile-align-center elementor-widget elementor-widget-button" data-element_type="widget" data-id="1fb259c" data-widget_type="button.default">
#             <div class="elementor-widget-container">
#              <div class="elementor-button-wrapper">
#               <a class="elementor-button-link elementor-button elementor-size-sm" href="https://timemachinetheband.com/contact-time-machine/" role="button">
#                <span class="elementor-button-content-wrapper">
#                 <span class="elementor-button-text">
#                  GET IN TOUCH WITH US
#                 </span>
#                </span>
#               </a>
#              </div>
#             </div>
#            </div>
#            <div class="elementor-element elementor-element-781c2e07 elementor-widget elementor-widget-text-editor" data-element_type="widget" data-id="781c2e07" data-widget_type="text-editor.default">
#             <div class="elementor-widget-container">
#              <div class="elementor-text-editor elementor-clearfix">
#               <p>
#                Copyright © 2021 Time Machine The Band.
#                <br/>
#                Designed by
#                <a href="https://adrianrae.co">
#                 Adrian Rae
#                </a>
#                .
#               </p>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </section>
#     </div>
#    </div>
#   </div>
#   <!-- #page -->
#   <script defer="" id="jquery-ui-core-js" src="https://timemachinetheband.com/wp-includes/js/jquery/ui/core.min.js">
#   </script>
#   <script defer="" id="jquery-ui-datepicker-js" src="https://timemachinetheband.com/wp-includes/js/jquery/ui/datepicker.min.js">
#   </script>
#   <script defer="" id="jquery-ui-datepicker-js-after">
#    jQuery(document).ready(function(jQuery){jQuery.datepicker.setDefaults({"closeText":"Close","currentText":"Today","monthNames":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthNamesShort":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"nextText":"Next","prevText":"Previous","dayNames":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"dayNamesShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"dayNamesMin":["S","M","T","W","T","F","S"],"dateFormat":"MM d, yy","firstDay":0,"isRTL":false});});
#   </script>
#   <script defer="" id="mec-typekit-script-js" src="https://timemachinetheband.com/wp-content/uploads/siteground-optimizer-assets/mec-typekit-script.min.js">
#   </script>
#   <script defer="" id="featherlight-js" src="https://timemachinetheband.com/wp-content/uploads/siteground-optimizer-assets/featherlight.min.js">
#   </script>
#   <script defer="" id="mec-select2-script-js" src="https://timemachinetheband.com/wp-content/plugins/modern-events-calendar-lite/assets/packages/select2/select2.full.min.js">
#   </script>
#   <script defer="" id="mec-tooltip-script-js" src="https://timemachinetheband.com/wp-content/uploads/siteground-optimizer-assets/mec-tooltip-script.min.js">
#   </script>
#   <script defer="" id="mec-lity-script-js" src="https://timemachinetheband.com/wp-content/plugins/modern-events-calendar-lite/assets/packages/lity/lity.min.js">
#   </script>
#   <script defer="" id="mec-colorbrightness-script-js" src="https://timemachinetheband.com/wp-content/plugins/modern-events-calendar-lite/assets/packages/colorbrightness/colorbrightness.min.js">
#   </script>
#   <script defer="" id="mec-owl-carousel-script-js" src="https://timemachinetheband.com/wp-content/plugins/modern-events-calendar-lite/assets/packages/owl-carousel/owl.carousel.min.js">
#   </script>
#   <script id="astra-theme-js-js-extra">
#    var astra = {"break_point":"921","isRtl":""};
#   </script>
#   <script defer="" id="astra-theme-js-js" src="https://timemachinetheband.com/wp-content/themes/astra/assets/js/minified/style.min.js">
#   </script>
#   <script defer="" id="siteground-optimizer-lazy-sizes-js-js" src="https://timemachinetheband.com/wp-content/plugins/sg-cachepress/assets/js/lazysizes.min.js">
#   </script>
#   <script id="c8b00ef5c-js-extra">
#    var localize = {"ajaxurl":"https:\/\/timemachinetheband.com\/wp-admin\/admin-ajax.php","nonce":"8872e22a92","i18n":{"added":"Added ","compare":"Compare","loading":"Loading..."}};
#   </script>
#   <script defer="" id="c8b00ef5c-js" src="https://timemachinetheband.com/wp-content/uploads/essential-addons-elementor/c8b00ef5c.min.js">
#   </script>
#   <script id="wp-embed-js" src="https://timemachinetheband.com/wp-includes/js/wp-embed.min.js">
#   </script>
#   <script id="smartmenus-js" src="https://timemachinetheband.com/wp-content/plugins/elementor-pro/assets/lib/smartmenus/jquery.smartmenus.min.js">
#   </script>
#   <script id="elementor-pro-webpack-runtime-js" src="https://timemachinetheband.com/wp-content/plugins/elementor-pro/assets/js/webpack-pro.runtime.min.js">
#   </script>
#   <script id="elementor-webpack-runtime-js" src="https://timemachinetheband.com/wp-content/plugins/elementor/assets/js/webpack.runtime.min.js">
#   </script>
#   <script id="elementor-frontend-modules-js" src="https://timemachinetheband.com/wp-content/plugins/elementor/assets/js/frontend-modules.min.js">
#   </script>
#   <script id="elementor-pro-frontend-js-before">
#    var ElementorProFrontendConfig = {"ajaxurl":"https:\/\/timemachinetheband.com\/wp-admin\/admin-ajax.php","nonce":"0312395422","urls":{"assets":"https:\/\/timemachinetheband.com\/wp-content\/plugins\/elementor-pro\/assets\/"},"i18n":{"toc_no_headings_found":"No headings were found on this page."},"shareButtonsNetworks":{"facebook":{"title":"Facebook","has_counter":true},"twitter":{"title":"Twitter"},"google":{"title":"Google+","has_counter":true},"linkedin":{"title":"LinkedIn","has_counter":true},"pinterest":{"title":"Pinterest","has_counter":true},"reddit":{"title":"Reddit","has_counter":true},"vk":{"title":"VK","has_counter":true},"odnoklassniki":{"title":"OK","has_counter":true},"tumblr":{"title":"Tumblr"},"digg":{"title":"Digg"},"skype":{"title":"Skype"},"stumbleupon":{"title":"StumbleUpon","has_counter":true},"mix":{"title":"Mix"},"telegram":{"title":"Telegram"},"pocket":{"title":"Pocket","has_counter":true},"xing":{"title":"XING","has_counter":true},"whatsapp":{"title":"WhatsApp"},"email":{"title":"Email"},"print":{"title":"Print"}},"facebook_sdk":{"lang":"en_US","app_id":""},"lottie":{"defaultAnimationUrl":"https:\/\/timemachinetheband.com\/wp-content\/plugins\/elementor-pro\/modules\/lottie\/assets\/animations\/default.json"}};
#   </script>
#   <script id="elementor-pro-frontend-js" src="https://timemachinetheband.com/wp-content/plugins/elementor-pro/assets/js/frontend.min.js">
#   </script>
#   <script id="elementor-waypoints-js" src="https://timemachinetheband.com/wp-content/plugins/elementor/assets/lib/waypoints/waypoints.min.js">
#   </script>
#   <script id="swiper-js" src="https://timemachinetheband.com/wp-content/plugins/elementor/assets/lib/swiper/swiper.min.js">
#   </script>
#   <script id="share-link-js" src="https://timemachinetheband.com/wp-content/plugins/elementor/assets/lib/share-link/share-link.min.js">
#   </script>
#   <script id="elementor-dialog-js" src="https://timemachinetheband.com/wp-content/plugins/elementor/assets/lib/dialog/dialog.min.js">
#   </script>
#   <script id="elementor-frontend-js-before">
#    var elementorFrontendConfig = {"environmentMode":{"edit":false,"wpPreview":false,"isScriptDebug":false},"i18n":{"shareOnFacebook":"Share on Facebook","shareOnTwitter":"Share on Twitter","pinIt":"Pin it","download":"Download","downloadImage":"Download image","fullscreen":"Fullscreen","zoom":"Zoom","share":"Share","playVideo":"Play Video","previous":"Previous","next":"Next","close":"Close"},"is_rtl":false,"breakpoints":{"xs":0,"sm":480,"md":768,"lg":1025,"xl":1440,"xxl":1600},"responsive":{"breakpoints":{"mobile":{"label":"Mobile","value":767,"default_value":767,"direction":"max","is_enabled":true},"mobile_extra":{"label":"Mobile Extra","value":880,"default_value":880,"direction":"max","is_enabled":false},"tablet":{"label":"Tablet","value":1024,"default_value":1024,"direction":"max","is_enabled":true},"tablet_extra":{"label":"Tablet Extra","value":1200,"default_value":1200,"direction":"max","is_enabled":false},"laptop":{"label":"Laptop","value":1366,"default_value":1366,"direction":"max","is_enabled":false},"widescreen":{"label":"Widescreen","value":2400,"default_value":2400,"direction":"min","is_enabled":false}}},"version":"3.4.2","is_static":false,"experimentalFeatures":{"e_import_export":true,"landing-pages":true,"elements-color-picker":true,"admin-top-bar":true,"form-submissions":true,"video-playlist":true},"urls":{"assets":"https:\/\/timemachinetheband.com\/wp-content\/plugins\/elementor\/assets\/"},"settings":{"page":[],"editorPreferences":[]},"kit":{"active_breakpoints":["viewport_mobile","viewport_tablet"],"global_image_lightbox":"yes","lightbox_enable_counter":"yes"},"post":{"id":106,"title":"Song%20List%20%E2%80%93%20Time%20Machine","excerpt":"","featuredImage":"https:\/\/timemachinetheband.com\/wp-content\/uploads\/2020\/02\/TM-Logo-Featured-Image-Preview-1024x544.jpg"}};
#   </script>
#   <script id="elementor-frontend-js" src="https://timemachinetheband.com/wp-content/plugins/elementor/assets/js/frontend.min.js">
#   </script>
#   <script id="pro-preloaded-elements-handlers-js" src="https://timemachinetheband.com/wp-content/plugins/elementor-pro/assets/js/preloaded-elements-handlers.min.js">
#   </script>
#   <script id="preloaded-modules-js" src="https://timemachinetheband.com/wp-content/plugins/elementor/assets/js/preloaded-modules.min.js">
#   </script>
#   <script id="e-sticky-js" src="https://timemachinetheband.com/wp-content/plugins/elementor-pro/assets/lib/sticky/jquery.sticky.min.js">
#   </script>
#   <script>
#    /(trident|msie)/i.test(navigator.userAgent)&&document.getElementById&&window.addEventListener&&window.addEventListener("hashchange",function(){var t,e=location.hash.substring(1);/^[A-z0-9_-]+$/.test(e)&&(t=document.getElementById(e))&&(/^(?:a|select|input|button|textarea)$/i.test(t.tagName)||(t.tabIndex=-1),t.focus())},!1);
#   </script>
#  </body>
# </html>

# %% [markdown]
# ### find artist & song table

# %%
table = soup.find_all('table')[0]

# %% [markdown]
# ### loop through and find song and artist

# %%
table_rows = table.find_all('tr')
for tr in table_rows:
    td = tr.find_all('td')
    row = [i.text for i in td]
    print(row)
# Out:
# []
# ['2PAC / DR. DRE / ROGER TROUTMAN', 'CALIFORNIA LOVE']
# ['3 DOORS DOWN', 'KRYPTONITE']
# ['38 SPECIAL', 'CAUGHT UP IN YOU']
# ['38 SPECIAL', 'HOLD ON LOOSELY']
# ['311', 'ALL MIXED UP']
# ['A TASTE OF HONEY', 'BOOGIE OOGIE OOGIE']
# ['ABBA', 'DANCIN QUEEN']
# ['AC/DC', 'HIGHWAY TO HELL']
# ['AC/DC', 'SHOOK ME ALL NIGHT LONG']
# ['ACE OF BASE', 'THE SIGN']
# ['ADELE', 'MAKE YOU FEEL MY LOVE']
# ['ADELE', 'ROLLING IN THE DEEP']
# ['AEROSMITH', 'DREAM ON']
# ['AEROSMITH', 'SWEET EMOTION']
# ['AEROSMITH', 'WALK THIS WAY']
# ['AH HA', 'TAKE ON ME']
# ['AL GREEN', "LET'S STAY TOGETHER"]
# ['AL JARREAU', 'BOOGIE DOWN']
# ['ALAN JACKSON', 'LIKE RED ON A ROSE']
# ['ALANIS MORISSETTE', 'HAND IN MY POCKET']
# ['ALANIS MORISSETTE', 'YOU OUGHTA KNOW']
# ['ALANNAH MYLES', 'BLACK VELVET']
# ['ALICE IN CHAINS', 'MAN IN A BOX']
# ['ALICIA KEYS', "FALLIN'"]
# ['ALICIA KEYS', 'IF I AINT GOT YOU']
# ['ALICIA KEYS / JAY-Z', 'EMPIRE STATE OF MIND']
# ['ALLISON KRAUSS', 'WHEN YOU SAY NOTHING AT ALL']
# ['AMERICA', 'TIN MAN']
# ['AMERICAN AUTHORS', 'BEST DAY OF MY LIFE']
# ['AMY WINEHOUSE', 'REHAB']
# ['AMY WINEHOUSE', 'VALERIE']
# ['ANDY GRAMMER', "HONEY I'M GOOD"]
# ['ANDY GRIGS', "I'LL GO CRAZY"]
# ['ANITA WARD', 'RING MY BELL']
# ['ANNE-MARIE', '2002']
# ['AQUA', 'BARBIE GIRL']
# ['ARETHA FRANKLIN', 'CHAIN OF FOOLS']
# ['ARETHA FRANKLIN', 'RESPECT']
# ['ARIANA GRANDE', 'BREAK FREE']
# ['ARIANA GRANDE', 'INTO YOU']
# ['ARIANA GRANDE', 'PROBLEM']
# ['ARIANA GRANDE', 'THE WAY']
# ['ARIANA GRANDE / JESSIE J / NICKI MINAJ', 'BANG BANG']
# ['AUDIOSLAVE', 'LIKE A STONE']
# ['AUTOGRAPH', 'TURN UP THE RADIO']
# ['AVICII', 'WAKE ME UP']
# ['AVRIL LAVIGNE', 'I’M WITH YOU']
# ['AVRIL LAVIGNE', 'SK8R BOI']
# ['AVRIL LAVIGNE', 'WHAT THE HELL']
# ['B.O.B. FT. BRUNO MARS', 'NOTHIN ON YOU']
# ['BACKSTREET BOYS', "EVERYBODY (BACKSTREET'S BACK)"]
# ['BACKSTREET BOYS', 'I WANT IT THAT WAY']
# ['BACKSTREET BOYS', 'QUIT PLAYING GAMES (WITH MY HEART)']
# ['BANANARAMA', 'VENUS']
# ['BARENAKED LADIES', 'IT’S ALL BEEN DONE']
# ['BARENAKED LADIES', 'ONE WEEK']
# ['BEASTIE BOYS', 'FIGHT FOR YOUR RIGHT TO PARTY']
# ['BEE GEES', 'STAYIN ALIVE']
# ['BEE GEES', 'YOU SHOULD BE DANCIN']
# ['BEL DIV DEVOE', 'DO ME BABY']
# ['BEL DIV DEVOE', 'POISON']
# ['BEN E. KING', 'STAND BY ME']
# ['BEYONCE', 'CRAZY IN LOVE']
# ['BEYONCE', 'DÉJÀ VU']
# ['BEYONCE', 'LOVE ON TOP']
# ['BEYONCE', 'NAUGHTY GIRL']
# ['BEYONCE', 'SINGLE LADIES']
# ['BEYONCE', 'SWEET DREAMS']
# ['BIG N RICH', 'SAVE A HORSE RIDE A COWBOY']
# ['BILLIE OCEAN', 'CARRIBEAN QUEEN']
# ['BILLY CURRINGTON', 'LET ME DOWN EASY']
# ['BILLY IDOL', 'REBEL YELL']
# ['BILLY IDOL', 'WHITE WEDDING']
# ['BILLY JOEL', 'JUST THE WAY YOU ARE']
# ['BILLY JOEL', 'THE RIVER OF DREAMS']
# ['BILLY SQUIER', 'EVERYBODY WANTS YOU']
# ['BLACK EYED PEAS', 'BOOM BOOM POW']
# ['BLACK EYED PEAS', 'I GOT A FEELING']
# ['BLACK EYED PEAS', 'MEET ME HALF WAY']
# ['BLACKHAWK', 'GOODBYE SAYS IT ALL']
# ['BLACKSTREET', 'NO DIGGITY']
# ['BLIND MELON', 'NO RAIN']
# ['BLINK-182', 'ALL THE SMALL THINGS']
# ['BLONDIE', 'CALL ME']
# ['BLONDIE', 'HEART OF GLASS']
# ['BLU CANTRELL', "HIT 'EM UP STYLE (OOPS!)"]
# ['BLUE COUNTY', 'GOOD LITTLE GIRLS']
# ['BLUR', 'SONG 2']
# ['BOB SEGER', 'OLD TIME ROCK AND ROLL']
# ['BOBBY BROWN', 'EVERY LITTLE STEP']
# ['BOBBY BROWN', 'MY PREROGATIVE']
# ['BOBBY DARIN', 'MACK THE KNIFE']
# ['BON JOVI', 'IT’S MY LIFE']
# ['BON JOVI', 'LIVIN ON A PRAYER']
# ['BON JOVI', 'RUNAWAY']
# ['BON JOVI', 'WANTED DEAD OR ALIVE']
# ['BON JOVI', 'YOU GIVE LOVE A BAD NAME']
# ['BONNIE RAITT', 'SOMETHING TO TALK ABOUT']
# ['BOSTON', 'MORE THAN A FEELING']
# ['BOWLING FOR SOUP', '1985']
# ['BRAD PAISLEY', 'CELEBRITY']
# ['BRAD PAISLEY', 'ME NEITHER']
# ['BRAD PAISLEY', 'THEN']
# ['BREATHE CAROLINA', 'BLACKOUT']
# ['BRENDA LEE', "ROCKIN' AROUND THE CHRISTMAS TREE"]
# ['BRIAN MCKNIGHT', 'ANYTIME']
# ['BRICK', 'DAZZ']
# ['BRITNEY SPEARS', 'HIT ME BABY ONE MORE TIME']
# ['BRITNEY SPEARS', 'TOXIC']
# ['BROOKS & DUNN', "BOOT SCOOTIN' BOOGIE"]
# ['BROOKS & DUNN', 'HUSBANDS & WIVES']
# ['BROOKS & DUNN', 'MY MARIA']
# ['BROOKS & DUNN', 'NEON MOON']
# ['BROOKS & DUNN', 'NEXT BROKEN HEART']
# ['BROOKS & DUNN', "YOU'RE GONNA MISS ME WHEN I'M GONE"]
# ['BRUCE SPRINGSTEEN', 'SANTA CLAUS IS COMING TO TOWN']
# ['BRUNO MARS', '24K MAGIC']
# ['BRUNO MARS', 'CHUNKY']
# ['BRUNO MARS', 'LOCKED OUT OF HEAVEN']
# ['BRUNO MARS', 'THAT’S WHAT I LIKE']
# ['BRUNO MARS', 'THE LAZY SONG']
# ['BRUNO MARS', 'TREASURE']
# ['BRUNO MARS / Mark Ronson', 'UPTOWN FUNK']
# ['BRYAN ADAMS', 'CUTS LIKE A KNIFE']
# ['BRYAN ADAMS', 'HAVE YOU EVER LOVED A WOMAN']
# ['BRYAN ADAMS', 'SUMMER OF 69']
# ['BRYAN ADAMS / Tina Turner', 'IT’S ONLY LOVE']
# ['BUCKCHERRY', 'CRAZY BITCH']
# ['CALLOWAY', 'I WANNA BE RICH']
# ['CALVIN HARRIS', 'FEEL SO CLOSE']
# ['CALVIN HARRIS / PHARRELL WILLIAMS / KATY PERRY', 'FEELS']
# ['CALVIN HARRIS / RIHANNA', 'THIS IS WHAT YOU CAME FOR']
# ['CAMEO', 'WORD UP']
# ['CAMILA CABELLO', 'HAVANA']
# ['CANNED HEAT', 'GOING UP TO THE COUNTRY']
# ['CAPTAIN & TENNILLE', 'LOVE WILL KEEP US TOGETHER']
# ['CARL CARLTON', "SHE'S A BAD MAMA JAMMA"]
# ['CARLY RAE JEPSEN', 'CALL ME MAYBE']
# ['CARRIE UNDERWOOD', 'BEFORE HE CHEATS']
# ['CARRIE UNDERWOOD', 'GOOD GIRL']
# ['CARRIE UNDERWOOD', 'LAST NAME']
# ['CASCADA', 'EVACUATE THE DANCE FLOOR']
# ['CE LO GREEN', 'FORGET YOU']
# ['CELIA CRUZ', 'LA VIDA ES UN CARNAVAL']
# ['CHAKA KHAN', 'I FEEL FOR YOU']
# ['CHAKA KHAN', 'TELL ME SOMETHING GOOD']
# ['CHARLIE DANIELS BAND', 'DEVIL WENT DOWN TO GEORGIA']
# ['cheap trick', 'i want you to want me']
# ['cher', 'believe']
# ['cher lloyd', 'want u back']
# ['cheryl lynn', 'to be real']
# ['chic', 'good times']
# ['chic', 'le freak']
# ['charlie puth', 'how long']
# ['chris brown', 'she ain’t you']
# ['chris brown / pitbull', 'fun']
# ['chris isaak', 'wicked game']
# ['chris stapleton', 'millionaire']
# ['CHRIS STAPLETON', 'tennessee whiskey']
# ['christina aguilera', 'ain’t no other man']
# ['CHRISTINA AGUILERA', 'come on over']
# ['CHRISTINA AGUILERA', 'genie in a bottle']
# ['CHRISTMAS', "BABY IT'S COLD OUTSIDE"]
# ['CHRISTMAS', 'HAVE YOURSELF A MERRY LITTLE CHRISTMAS']
# ['CHRISTMAS', 'i’ll be home for christmas']
# ['CHRISTMAS', 'LET IT SNOW']
# ['CHRISTMAS', 'SANTA BABY']
# ['CHRISTMAS', 'THE CHRISTMAS SONG']
# ['CHRISTMAS', 'WINTER WONDERLAND']
# ['chromeo', "JEALOUS (I AIN'T WITH IT)"]
# ['chubby checker', 'the twist']
# ['chuck berry', 'johnny b. goode']
# ['CHUMBAWAMBA', 'TUBTHUMPING']
# ['citizen cope', 'sideways']
# ['CLEAN BANDIT & JESS GLYNNE', 'rather be']
# ['CLEAN BANDIT & JESS GLYNNE', 'real love']
# ['CLINT BLACK', 'a better man']
# ['COBRA STARSHIP', 'good girls go bad']
# ['COBRA STARSHIP', 'lucky']
# ['COLDPLAY', 'adventure of a lifetime']
# ['COLOR ME BADD', 'i wanna sex you up']
# ['COMMODORES', 'brick house']
# ['COMMODORES', 'easy']
# ['COMMODORES', 'lady (you bring me up)']
# ['COOLIO', "1, 2, 3, 4 (SUMPIN' NEW)"]
# ['counting crows', 'MR. JONES']
# ['courtney love / hole', 'violet']
# ['creed', 'higher']
# ['CREEDENCE CLEARWATER REVIVAL', 'bad moon rising']
# ['CREEDENCE CLEARWATER REVIVAL', 'down on the corner']
# ['CREEDENCE CLEARWATER REVIVAL', 'proud mary']
# ['CREEDENCE CLEARWATER REVIVAL', 'suzie q']
# ['cris cab', 'liar liar']
# ['cupid', 'cupid shuffle']
# ['cyndi lauper', 'girls just wanna have fun']
# ['daft punk', 'get lucky']
# ['dan & shay', 'from the ground up']
# ['dan hartman', 'i can dream about you']
# ['darius rucker', 'wagon wheel']
# ['darryl worley', 'awful beautiful life']
# ['dave matthews band', 'you and me']
# ['david allen coe', 'YOU NEVER EVEN CALL ME BY MY NAME']
# ['david bowie', 'china girl']
# ['DAVID BOWIE', 'lets dance']
# ['DAVID GUETTA / NICKI MINAJ', 'turn me on']
# ['DAVID GUETTA / RIHANNA', 'who’s that chick']
# ['DAVID GUETTA / SIA', 'TITANIUM']
# ['DAVID GUETTA / USHER', 'WITHOUT YOU']
# ['david lee murphy', 'dust on the bottle']
# ['david lee roth', 'just a gigalo']
# ['dead or alive', 'you spin me round']
# ['deana carter', 'strawberry wine']
# ['debarge', 'rhythm of the night']
# ['dee lite', 'groove is in the heart']
# ['deep blue something', "breakfast at tiffany's"]
# ['def leppard', 'photograph']
# ['DEF LEPPARD', 'pour some sugar']
# ['DEF LEPPARD', 'rock of ages']
# ['del shannon', 'runaway']
# ['DENIECE WILLIAMS', 'LETS HEAR IT FOR THE BOY']
# ["DEXY'S MIDNIGHT RUNNER", 'COME ON EILEEN']
# ['DIANA ROSS', 'UPSIDE DOWN']
# ['DIANA ROSS AND THE SUPREMES', 'COME SEE ABOUT ME']
# ['DIANA ROSS AND THE SUPREMES', "YOU CAN'T HURRY LOVE"]
# ['DIERKS BENTLEY', 'A LOT OF LEAVING LEFT TO DO']
# ['DIXIE CHICKS', 'goodbye earl']
# ['DIXIE CHICKS', 'TONIGHT THE HEARTACHES ON ME']
# ['DIXIE CHICKS', 'you can’t hurry love']
# ['DJ CASSIDY / JESSIE J / ROBIN THICKE', 'calling all hearts']
# ['dnce', 'body moves']
# ['dnce', 'cake by the ocean']
# ['dobie gray', 'drift away']
# ['don henley', 'boys of summer']
# ['don henley', 'dirty laundry']
# ['donna summer', 'bad girls']
# ['donna summer', 'hot stuff']
# ['donna summer', 'last dance']
# ['DR. DRE / 2PAC / ROGER TROUTMAN', 'california love']
# ['drake', "HOLD ON WE'RE GOING HOME"]
# ['dua lipa', 'new rules']
# ['duffy', 'mercy']
# ['duncan sheik', 'barely breathing']
# ['duran duran', 'girls on film']
# ['DURAN DURAN', 'hungry like the wolf']
# ['DURAN DURAN', 'reflex']
# ['DURAN DURAN', 'rio']
# ['dusty springfield', 'son of a preacher man']
# ['eagle-eye cherry', 'save tonight']
# ['EAGLES', 'hotel california']
# ['EAGLES', 'life in the fast lane']
# ['EAGLES', 'love will keep us alive']
# ['EAGLES', 'one of these nights']
# ['EAGLES', 'PLEASE COME HOME FOR CHRISTMAS']
# ['EAGLES', 'take it easy']
# ['EAGLES', 'tequila sunrise']
# ['EARTH WIND & FIRE', 'let’s groove tonight']
# ['EARTH WIND & FIRE', 'september']
# ['EARTH WIND & FIRE', 'shining star']
# ['Echosmith', 'cool kids']
# ['ed sherran', 'shape of you']
# ['ED SHERRAN', 'sing']
# ['ED SHERRAN', 'thinking out loud']
# ['eddie money', 'take me home tonight']
# ['edwin mccain', 'i’ll be']
# ['elle king', 'ex’s and oh’s']
# ['eli young band', 'my old man’s son']
# ['ellie goulding', 'lights']
# ['elton john', 'blessed']
# ['ELTON JOHN', 'CAN YOU FEEL THE LOVE TONIGHT']
# ['ELTON JOHN & KIKI DEE', "DON'T GO BREAKING MY HEART"]
# ['ELVIS PRESLEY', 'suspicious minds']
# ['ELVIS PRESLEY', 'the wonder of you']
# ['emeli sande', 'next to me']
# ['en vogue', 'free your mind']
# ['enrique iglesias', 'tonight i’m loving you']
# ['eric clapton', 'YOU LOOK WONDERFUL TONIGHT']
# ['erykah badu', 'tyrone']
# ['etta james', 'at last']
# ['e.u.', 'DA butt']
# ['europe', 'THE FINAL COUNTDOWN']
# ['eurythmics', 'SWEET DREAMS (ARE MADE OF THIS)']
# ['evanescence', 'bring me to life']
# ['eve 6', '']
# ['faith no more', 'epic']
# ['fall out boy', 'beat it']
# ['FALL OUT BOY', 'MY SONGS KNOW WHAT YOU DID IN THE DARK (LIGHT EM UP)']
# ['fastball', 'the way']
# ['fergie', 'big girls don’t cry']
# ['FERGIE', 'clumsy']
# ['FERGIE', 'glamorous']
# ['fifth harmony', 'worth it']
# ['fine young cannibals', 'she drives me crazy']
# ['finger 11', 'paralyzer']
# ['firehouse', 'love of a lifetime']
# ['fitz and the tantrums', 'the walker']
# ['five for fighting', '100 years']
# ['fleetwood mac', 'Dreams']
# ['flo rida', 'good feeling']
# ['flo rida', 'wild ones']
# ['FLO RIDA / ROBIN THICKE / VERDINE WHITE', 'i don’t like it I love it']
# ['florida georgia line', 'cruise']
# ['FLORIDA GEORGIA LINE', 'round here']
# ['flock of seagulls', 'i ran']
# ['foo fighters', 'learn to fly']
# ['FOO FIGHTERS', 'rope']
# ['FOO FIGHTERS', 'times like these']
# ['FOREIGNER', 'cold as ice']
# ['FOREIGNER', 'feels like the first time']
# ['FOREIGNER', 'hot blooded']
# ['FOREIGNER', 'waiting for a girl like you']
# ['fountains of wayne', 'stacy’s mom']
# ['four non blondes', 'what’s up']
# ['four tops', "I CAN'T HELP MYSELF (SUGAR PIE HONEY BUNCH)"]
# ['frank sinatra', 'fly me to the moon']
# ['FRANK SINATRA', 'mack the knife']
# ['FRANK SINATRA', 'New York, New York']
# ['FRANK SINATRA', 'summer wind']
# ['FRANK SINATRA', 'that’s life']
# ['frankie goes to hollywood', 'relax']
# ['FRANKIE VALLIE AND THE VALLIANTS', 'oh what a night']
# ['free', 'all right now']
# ['Garth Brooks', 'callin’ baton rouge']
# ['GARTH BROOKS', 'friends in low places']
# ['GARTH BROOKS', 'it’s your song']
# ['GARTH BROOKS', 'the dance']
# ['gary numan', 'cars']
# ['gavin degraw', 'i don’t wanna be']
# ['gavin degraw', 'i’m in love with a girl']
# ['george clinton', 'atomic dog']
# ['george michael', 'faith']
# ['GEORGE MICHAEL', 'i want your sex']
# ['george strait', 'i can still make cheyenne']
# ['GEORGE STRAIT', 'the chair']
# ['gin blossoms', 'follow you down']
# ['GIN BLOSSOMS', 'hey jealousy']
# ['GIN BLOSSOMS', 'i found out about you']
# ['ginuwine', 'pony']
# ['GLADYS KNIGHT', 'midnight train to georgia']
# ['gloria estefan', 'conga']
# ['GLORIA ESTEFAN', 'RHYTHM IS GONNA GET YOU']
# ['gloria gaynor', 'i will survive']
# ['GNARLS BARKLEY', 'crazy']
# ['goo goo dolls', 'iris']
# ['GOO GOO DOLLS', 'slide']
# ['gorillaz', 'feel good inc.']
# ['gotye', 'SOMEBODY THAT I USE TO KNOW']
# ['GRACE POTTER AND THE NOCTURNALS', 'PARIS (OOH LA LA)']
# ['grease', 'summer nights']
# ['GREASE', 'you’re the one that i want']
# ['great white', 'once bitten twice shy']
# ['green day', 'basket case']
# ['green day', 'when i come around']
# ['gretchen wilson', 'here for the party']
# ['GRETCHEN WILSON', 'redneck woman']
# ['guns & roses', 'sweet child of mine']
# ['gwen stefani', 'sweet escape']
# ['GWEN STEFANI FEAT. EVE', 'rich girl']
# ['haddaway', 'what is love']
# ['HAL KETCHUM', 'i saw the light']
# ['HAL KETCHUM', 'point of rescue']
# ['hall & oates', 'i can’t for for that']
# ['HALL & OATES', 'kiss on my list']
# ['HALL & OATES', 'maneater']
# ['HALL & OATES', 'private eyes']
# ['hanson', 'mmmbop']
# ['harvey danger', 'flagpole sitta']
# ['heart', 'alone']
# ['heart', 'baracudda']
# ['heartland', 'i loved her first']
# ['heatwave', 'boogie nights']
# ['HOLE / COURTNEY LOVE', 'violet']
# ['HOOTIE & THE BLOWFISH', 'hold my hand']
# ['HOOTIE & THE BLOWFISH', 'only wanna be with you']
# ['HOT CHELLE RAE', 'tonight tonight']
# ['house of pain', 'jump around']
# ['howard jones', 'things can only get better']
# ['HUEY LEWIS & THE NEWS', 'do you believe in love']
# ['HUEY LEWIS & THE NEWS', 'heart and soul']
# ['HUEY LEWIS & THE NEWS', 'hip to be square']
# ['HUEY LEWIS & THE NEWS', 'i want a new drug']
# ['HUEY LEWIS & THE NEWS', 'power of love']
# ['hunter hayes', 'wanted']
# ['ian hunter', 'once bitten twice shy']
# ['iggy azalea', 'fancy']
# ['IGGY AZALEA / JENNIFER HUDSON', 'trouble']
# ['IGGY AZALEA / JENNIFER HUDSON', 'radioactive']
# ['incubus', 'drive']
# ['information society', 'what’s on your mind']
# ['ingrid michaelson', 'the way i am']
# ['inxs', 'i need you tonight']
# ['inxs', 'new sensation']
# ['izreal', 'over the rainbow']
# ['J. GEILS BAND', 'centerfold']
# ['J. GEILS BAND', 'freeze frame']
# ['JACKIE DESHANNON', 'WHAT THE WORLD NEEDS NOW IS LOVE']
# ['jackson 5', 'i want you back']
# ['james otto', 'just got started lovin’ you']
# ['james taylor', 'HOW SWEET IT IS (TO BE LOVED BY YOU)']
# ['jamie oneal', 'there is no arizona']
# ['JANET JACKSON', 'all for you']
# ['JANET JACKSON', 'black cat']
# ['JANET JACKSON', 'nasty']
# ['JANET JACKSON', 'that’s the way love goes']
# ['JANET JACKSON', 'WHAT HAVE YOU DONE FOR ME LATELY']
# ['JANET JACKSON', 'when i think of you']
# ['janis joplin', 'bobby mcgee']
# ['JANIS JOPLIN', 'piece of my heart']
# ['jason aldene', 'amarillo sky']
# ['JASON ALDENE / KELLY CLARKSON', "DON'T YOU WANNA STAY"]
# ['JASON DERULO', 'talk dirty']
# ['JASON DERULO', 'want to want me']
# ['jason mraz', 'i won’t give up']
# ['JASON MRAZ', 'i’m yours']
# ['JASON MRAZ / COLBIE CAILLAT', 'lucky']
# ['JAY AND THE AMERICANS', 'this magic moment']
# ['JAY-Z / ALICIA KEYS', 'Empire State of mind']
# ['JEFFERSON AIRPLANE', 'somebody to love']
# ['JENNIFER LOPEZ', "AIN'T IT FUNNY (MURDER REMIX)"]
# ['JENNIFER LOPEZ', 'let’s get loud']
# ['JENNIFER LOPEZ', 'on the floor']
# ['JENNIFER LOPEZ', 'play']
# ['JENNIFER PAIGE', 'crush']
# ['JESS GLYNNE', 'hold my hand']
# ['JESSIE J', 'domino']
# ['JESSIE J / DJ CASSIDY / ROBIN THICKE', 'CALLING ALL HEARTS']
# ['jesus jones', 'right here right now']
# ['jett', 'are you gonna be my girl']
# ['jimi hendrix', 'hey joe']
# ['JIMI HENDRIX', 'purple haze']
# ['JIMI HENDRIX', 'red house']
# ['JIMI HENDRIX', 'voodoo child']
# ['jimmy buffett', 'MARGARITAVILLE']
# ['jimmy eat world', 'the middle']
# ['jo dee messina', 'bye bye']
# ['JO DEE MESSINA', 'i’m alright']
# ['JO DEE MESSINA', 'my give a damn’s busted']
# ['joan jett', 'i love rock and roll']
# ['jocelyn brown', 'somebody else’s guy']
# ['joe cocker', 'feelin alright']
# ['JOE COCKER', 'unchain my heart']
# ['JOE COCKER', 'WITH A LITTLE HELP FROM MY FRIENDS']
# ['joey gian', 'what if i loved you']
# ['john lennon', 'imagine']
# ['john mayer', 'daughters']
# ['JOHN MAYER', 'no such thing']
# ['JOHN Melancamp', 'hurt so good']
# ['johnny cash', 'a boy named sue']
# ['JOHNNY CASH', 'folsom prison blues']
# ['JOHNNY CASH', 'i walk the line']
# ['jon pardi', 'head over boots']
# ['josh turner', 'your man']
# ['JOURNEY', 'anyway you want it']
# ['JOURNEY', 'be good to yourself']
# ['JOURNEY', 'don’t stop believin']
# ['JOURNEY', 'faithfully']
# ['JOURNEY', 'lights']
# ['JOURNEY', 'lovin touchin squeezin']
# ['JOURNEY', 'only the young']
# ['JOURNEY', 'send her my love']
# ['JOURNEY', 'separate ways']
# ['JOURNEY', 'stone in love']
# ['JOURNEY', "THE PARTY'S OVER (HOPELESSLY IN LOVE)"]
# ['JOURNEY', 'wheel in the sky']
# ['justin bieber', 'baby']
# ['JUSTIN BIEBER', 'boyfriend']
# ['JUSTIN BIEBER & LUIS FONSI & DADDY YANKEE', 'despacito']
# ['justin timberlake', 'can’t stop the feeling']
# ['JUSTIN TIMBERLAKE', 'like i love you']
# ['JUSTIN TIMBERLAKE', 'love stoned']
# ['JUSTIN TIMBERLAKE', 'rock your body']
# ['JUSTIN TIMBERLAKE', 'sexyback']
# ['JUSTIN TIMBERLAKE', 'suit and tie']
# ['JUSTIN TIMBERLAKE / THE LONELY ISLAND', 'dick in a box']
# ['KANYE WEST FT. ESTELLE', 'american boy']
# ['karmin', 'brokenhearted']
# ['KATRINA & THE WAVES', 'walkin on sunshine']
# ['KATY PERRY', 'birthday']
# ['KATY PERRY', 'california girls']
# ['KATY PERRY', 'i kissed a girl']
# ['KATY PERRY', 'e.t.']
# ['KATY PERRY', 'hot & cold']
# ['KATY PERRY', 'roar']
# ['KATY PERRY / CALVIN HARRIS / PHARRELL WILLIAMS', 'feels']
# ['KC & THE SUNSHINE BAND', '(SHAKE, SHAKE, SHAKE) SHAKE YOUR BOOTY']
# ['KC & THE SUNSHINE BAND', 'boogie shoes']
# ['KC & THE SUNSHINE BAND', 'get down tonight']
# ['KC & THE SUNSHINE BAND', 'give it up']
# ['KC & THE SUNSHINE BAND', 'that’s the way (I like it)']
# ['KEITH URBAN', 'but for the grace of god']
# ['KEITH URBAN', 'little bit of everything']
# ['KEITH URBAN', 'somebody like you']
# ['KEITH URBAN', 'yo’re my better half']
# ['KEITH URBAN & CARRIE UNDERWOOD', 'the fighter']
# ['KELLY CLARKSON', 'don’t rush']
# ['KELLY CLARKSON', 'since you’ve been gone']
# ['KELLY CLARKSON / JASON ALDENE', 'don’t you wanna stay']
# ['kenny chesney', 'don’t happen twice']
# ['KENNY LOGGINS', 'footloose']
# ['KENNY LOGGINS', 'heart to heart']
# ['KENNY LOGGINS', 'i’m alright']
# ['ke$ha', 'blow']
# ['KE$HA', 'tic tok']
# ['KE$HA', 'we r who we r']
# ['KE$HA / PITBULL', 'timber']
# ['kid rock', 'all summer long']
# ['kid rock', 'cowboy']
# ['KID ROCK / SHERYL CROW', 'picture']
# ['kings of leon', 'use somebody']
# ['kiss', 'I WANNA ROCK AND ROLL ALL NIGHT']
# ['KLYMAXX', 'MEETING IN THE LADIES ROOM']
# ['KOOL & THE GANG', 'celebration']
# ['KOOL & THE GANG', 'get down on it']
# ['KOOL & THE GANG', 'ladies night']
# ['kt tunstall', 'BLACK HORSE AND THE CHERRY TREE']
# ['KYLIE MINOGUE', 'CANT GET YOU OUTTA MY HEAD']
# ['KYM WILDE', 'KEEP ME HANGIN ON']
# ['LADY ANTEBELLUM', 'bartender']
# ['LADY ANTEBELLUM', 'need you now']
# ['LADY ANTEBELLUM', 'you look good']
# ['lady gaga', 'bad romance']
# ['LADY GAGA', 'just dance']
# ['LADY GAGA', 'poker face']
# ['lanco', 'greatest love story']
# ['LEE ANN WOMACK', 'i hope you dance']
# ['LEE ANN WOMACK', 'little past little rock']
# ['LEE ANN WOMACK', 'talk to me']
# ['LEE ANN WOMACK', "YOU'VE GOT TO TALK TO ME"]
# ['LENNY KRAVITZ', 'ARE YOU GONNA GO MY WAY']
# ['LENNY KRAVITZ', "IT AIN'T OVER 'TIL IT'S OVER"]
# ['leona lewis', 'bleeding love']
# ['leroy parnell', 'hearts desire']
# ['LEROY PARNELL', 'take these chains']
# ['LES MISERABLES', 'bring him home']
# ['lifehouse', 'hanging by a moment']
# ['LIL NAS X FEAT. BILLY RAY CYRUS', 'old town road']
# ['LIONEL RICHIE', 'all night long']
# ['LIPPS INC.', 'funkytown']
# ['lit', 'my own worse enemy']
# ['little big town', 'pontoon']
# ['little texas', 'amy’s back in austin']
# ['live', 'i alone']
# ['lizzo', 'juice']
# ['LIZZO', 'truth hurts']
# ['Lmfao', 'party rock']
# ['LMFAO', 'sexy and i know it']
# ['los lonely boys', 'how far is heaven']
# ['lou bega', 'mambo #5']
# ['louis armstrong', 'mack the knife']
# ['loverboy', 'turn me loose']
# ['loverboy', 'workin for the weekend']
# ['LUIS FONSI & DADDY YANKEE & JUSTIN BIEBER', 'DESPACITO']
# ['LUKE BRYAN', 'COUNTRY GIRL (SHAKE IT FOR ME)']
# ['LUKE BRYAN', 'DRUNK ON YOU']
# ['lynard skynard', 'SWEET HOME ALABAMA']
# ['MACKLEMORE & RYAN LEWIS', 'can’t hold us']
# ['MACKLEMORE & RYAN LEWIS', 'thrift shop']
# ['Madness', 'our house']
# ['madonna', 'holiday']
# ['MADONNA', 'like a virgin']
# ['MADONNA', 'lucky star']
# ['MADONNA', 'material girl']
# ['MADONNA', 'vogue']
# ['MAGIc!', 'rude']
# ['marc anthony', 'i need to know']
# ['marc cohen', 'walkin in memphis']
# ['mariah carey', 'ALL I WANT FOR CHRISTMAS IS YOU']
# ['MARIAH CAREY', 'always be my baby']
# ['MARIAH CAREY', 'emotions']
# ['MARIAH CAREY', 'fantasy']
# ['mark morrison', 'return of the mack']
# ['MAROON 5', 'daylight']
# ['MAROON 5', 'don’t wanna know']
# ['MAROON 5', 'girls like you']
# ['MAROON 5', 'give a little more']
# ['MAROON 5', 'i won’t go home without you']
# ['MAROON 5', 'it was always you']
# ['MAROON 5', 'makes me wonder']
# ['MAROON 5', 'misery']
# ['MAROON 5', 'moves like jagger']
# ['MAROON 5', 'one more night']
# ['MAROON 5', 'she will be loved']
# ['MAROON 5', 'sugar']
# ['MAROON 5', 'sunday morning']
# ['MAROON 5', 'this love']
# ['MAROON 5', 'what lovers do']
# ['martina mcbride', 'a broken wing']
# ['MARTINA MCBRIDE', 'independence day']
# ['MARTINA MCBRIDE', 'valentine']
# ['MARTINA MCBRIDE', 'whatever you say']
# ['marvin gaye', 'HOW SWEET IT IS (TO BE LOVED BY YOU)']
# ['MARVIN GAYE', 'I HEARD IT THROUGH THE GRAPEVINE']
# ['MARVIN GAYE', "LET'S GET IT ON"]
# ['MARVIN GAYE & TAMMI TERRELL', "AIN'T NO MOUNTAIN HIGH ENOUGH"]
# ['MATCHBOX 20', '3 a.m.']
# ['MATCHBOX 20', 'push']
# ['MATCHBOX 20', 'real world']
# ['MATTHEWS SOUTHERN COMFORT', 'woodstock']
# ['MEGHAN TRAINOR', 'all about that bass']
# ['MEGHAN TRAINOR', 'lips are movin']
# ['MEGHAN TRAINOR', 'me too']
# ['MEGHAN TRAINOR', 'watch me do']
# ['MELISSA ETHERIDGE', 'i’m the only one']
# ['men at work', 'land down under']
# ['men at work', 'who can it be now']
# ['Meredith brooks', 'bitch']
# ['merle haggard', 'workin man blues']
# ['michael bolton', 'daddy’s little girl']
# ['michael buble', 'Everything']
# ['MICHAEL BUBLE', 'HAVEN’T MET YOU YET']
# ['MICHAEL BUBLE', 'save the last dance for me']
# ['MICHAEL JACKSON', 'beat it']
# ['MICHAEL JACKSON', 'billie jean']
# ['MICHAEL JACKSON', 'black or white']
# ['MICHAEL JACKSON', 'don’t stop til you get enough']
# ['MICHAEL JACKSON', 'p.y.t. (pretty young thing)']
# ['MICHAEL JACKSON', 'rock with you']
# ['MICHAEL JACKSON', 'SHAKE YOUR BODY DOWN TO THE GROUND']
# ['MICHAEL JACKSON', 'smooth criminal']
# ['MICHAEL JACKSON', 'the way you make me feel']
# ['MICHAEL JACKSON', 'thriller']
# ['MICHAEL JACKSON', 'wanna be startin something']
# ['MICHAEL JACKSON', 'workin day and night']
# ['MICHAEL JACKSON/PAUL MCCARTNEY', 'say say say']
# ['Miley Cyrus', 'party in the usa']
# ['milli vanilli', 'girl you know it’s true']
# ['missy elliott', 'work it']
# ['mkto', 'classic']
# ['modern english', 'i melt with you']
# ['montel jordan', 'this is how we do it']
# ['MORRIS DAY & THE TIME', 'jungle love']
# ['MORRIS DAY & THE TIME', 'the bird']
# ['MOTLEY CRUE', 'home sweet home']
# ['mr. mister', 'broken wings']
# ['MR. MISTER', 'kyrie']
# ['muse', 'hysteria']
# ['MUSE', 'madness']
# ['MUSE', 'uprising']
# ['n sync', 'bye bye bye']
# ['N SYNC', 'it’s gonna be me']
# ['N SYNC', 'pop']
# ['naked eyes', 'ALWAYS SOMETHING THERE TO REMIND ME']
# ['nat king cole', 'l-o-v-e']
# ['neil diamond', 'sweet caroline']
# ['nelly', 'hot in here']
# ['nelly furtado', 'say it right']
# ['neon trees', 'animal']
# ['NEON TREES', 'everybody talks']
# ['NEON TREES', 'sleeping with my friend']
# ['new radicals', 'you get what you give']
# ['next', 'too close']
# ['ne-yo', 'closer']
# ['ne-yo / pitbull', 'give me everything']
# ['NICK JONAS', 'jealous']
# ['NICK JONAS', 'levels']
# ['nicki minaj', 'starships']
# ['NICKI MINAJ / DAVID GUETTA', 'turn me on']
# ['nico & vinz', 'am i wrong']
# ['night ranger', 'Don’t tell me you love me']
# ['NIGHT RANGER', 'sister christian']
# ['nine days', 'Absolutely (Story of a girl)']
# ['nirvana', 'smells like teen spirit']
# ['nitty gritty dirt band', 'fishin’ in the dark']
# ['no doubt', 'don’t speak']
# ['NO DOUBT', 'hella good']
# ['NO DOUBT', 'it’s my life']
# ['NO DOUBT', 'just a girl']
# ['norah jones', 'don’t know why']
# ['NOTORIOUS B.I.G. / PUFF DADDY / MASE', 'mo money mo problems']
# ['nu shooz', 'i can’t wait']
# ['oasis', 'wonderwall']
# ['olly murs', 'troublemaker']
# ['OLLY MURS', 'wrapped up']
# ['omi', 'cheerleader']
# ['onerepublic', 'apologize']
# ['ONEREPUBLIC', 'counting stars']
# ['ONEREPUBLIC', 'love runs out']
# ['otis redding', 'sitting on the dock of the bay']
# ['outkast', 'hey ya']
# ['OUTKAST', 'the way you move']
# ['owl city', 'fireflies']
# ['ozzy', 'crazy train']
# ['pam tillis', 'shake the sugar tree']
# ['paramore', 'ain’t it fun']
# ['pat benatar', 'HIT ME WITH YOUR BEST SHOT']
# ['PAT BENATAR', 'HEARTBREAKER']
# ['Patsy Cline', 'CRAZY']
# ['Patti Labelle', 'LADY MARMALADE']
# ['paul mccartney', 'WONDERFUL CHRISTMAS TIME']
# ['paula abdul', 'straight up']
# ['pearl jam', 'even flow']
# ['peter gabriel', 'sledgehammer']
# ['pharrell williams', 'happy']
# ['PHARRELL WILLIAMS / CALVIN HARRIS / KATY PERRY', 'feels']
# ['PHIL COLLINS', 'you can’t hurry love']
# ['PHIL COLLINS / PHILIP BAILEY', 'easy lover']
# ['pink', 'get the party started']
# ['PITBULL / CHRIS BROWN', 'fun']
# ['PITBULL / CHRIS BROWN', 'timber']
# ['POISON', 'nothin but a good time']
# ['POISON', 'talk dirty to me']
# ['PRINCE', 'cream']
# ['PRINCE', 'i wanna be your lover']
# ['PRINCE', 'kiss']
# ['PRINCE', 'let’s go crazy']
# ['PRINCE', 'purple rain']
# ['PRINCE', 'raspberry beret']
# ['PRINCE', 'THE MOST BEAUTIFUL GIRL IN THE WORLD']
# ['PRINCE', 'when doves cry']
# ['pussycat dolls', 'don’t cha']
# ['Queen', 'another one bites the dust']
# ['Queen', 'bohemian rhapsody']
# ['R. Kelly', 'ignition (remix)']
# ['r.e.m.', 'losing my religion']
# ['radiohead', 'creep']
# ['randy newman', 'you’ve got a friend in me']
# ['randy travis', 'forever and ever amen']
# ['rascal flatts', 'fast cars and freedom']
# ['RASCAL FLATTS', 'life is a highway']
# ['RASCAL FLATTS', 'me and my gang']
# ['RASCAL FLATTS', 'my wish']
# ['RASCAL FLATTS', 'prayin’ for daylight']
# ['Ratt', 'Lay it down']
# ['ratt', 'Round and rounD']
# ['ray charles', 'Ain’t that love']
# ['ray lamontagne', 'you are the best thing']
# ['reba mcentire', 'Fancy']
# ['REBA MCENTIRE', 'Take it back']
# ['REBA MCENTIRE', 'Why Haven’t I heard from you']
# ['red hot chili peppers', 'Aeroplane']
# ['RED HOT CHILI PEPPERS', 'Dani California']
# ['RED HOT CHILI PEPPERS', 'Dark necessities']
# ['restless heart', 'the bluest eyes in texas']
# ['RESTLESS HEART', 'When she cries']
# ['rick astley', 'Never gonna give you up']
# ['rick james', 'Give it to me baby']
# ['RICK JAMES', 'Superfreak']
# ['RICK JAMES', 'You and I']
# ['rick springfield', 'Jessie’s Girl']
# ['ricky martin', 'Livin La vida Loca']
# ['RICKY MARTIN', 'Shake your bon bon']
# ['RICKY MARTIN', 'She Bangs']
# ['RIHANNA', 'Cheers (Drink to that)']
# ['RIHANNA', 'Disturbia']
# ['RIHANNA', 'only girl in the worlD']
# ['RIHANNA', 'please don’t stop the music']
# ['RIHANNA', 'Rude Boy']
# ['RIHANNA', 's & M']
# ['RIHANNA', 'umbrella']
# ['RIHANNA', 'we found love']
# ['RIHANNA / CALVIN HARRIS', 'this is what you came for']
# ['RIHANNA / DAVID GUETTA', 'who’s that chick']
# ['rixton', 'Me and my broken heart']
# ['robbie dupree', 'Steal Away']
# ['robert palmer', 'Addicted to love']
# ['robin thicke', 'blurred lines']
# ['ROBIN THICKE / DJ CASSIDY / JESSIE J', 'calling all hearts']
# ['ROD STEWART', 'if you think i’m sexy']
# ['ROD STEWART', 'our love is here to stay']
# ['ROD STEWART', 'twisting the night away']
# ['RODNEY FOSTER', 'just call me lonesome']
# ['ROGER TROUTMAN / 2PAC / DR. DRE', 'california love']
# ['rolling stones', 'honky tonk woman']
# ['ronnie milsap', 'stranger in my house']
# ['rose royce', 'car wash']
# ['roxette', 'the look']
# ['roy orbison', 'pretty woman']
# ['run d.m.c.', 'walk this way']
# ['sade', 'smooth operator']
# ['safetysuit', 'never stop (wedding version)']
# ['saga', 'on the loose']
# ['salt-n-pepa', 'shoop']
# ['SALT-N-PEPA', 'whatta man']
# ['sam cooke', 'you send me']
# ['sam smith', "i'm not the only one"]
# ['SAM SMITH', 'stay with me']
# ['sammy kershaw', 'third rate romance']
# ['santana', 'black magic woman']
# ['santana', 'evil ways']
# ['sara bareilles', 'i choose you']
# ['SARA BAREILLES', 'write you a love song']
# ['sara evans', 'born to fly']
# ['SARA EVANS', 'real fine place to start']
# ['scandal', 'the warrior']
# ['selena', 'AMOR PROHIBIDO']
# ['selena', 'bidi bidi bom bom']
# ['selena gomez', 'love you like a love song']
# ['semisonic', 'closing time']
# ['seven mary three', 'cumbersome']
# ['shaggy', "it wasn't me"]
# ['SHANIA TWAIN', 'any man of mine']
# ['SHANIA TWAIN', "i'm outta here"]
# ['SHANIA TWAIN', 'man! I feel like a woman']
# ['shawn colvin', 'sunny came home']
# ['shawn mendes', 'stitches']
# ['SHAWN MENDES', "there's nothing holding me back"]
# ['SHAWN MENDES & CAMILA CABELLO', 'senorita']
# ['shawn mullins', 'lullaby']
# ['sherrie austin', 'son of a preacher man']
# ['sheryl crow', 'first cut is the deepest']
# ['SHERYL CROW / KID ROCK', 'picture']
# ['SIA / DAVID GUETTA', 'titanium']
# ['simple minds', "don't you forget about me"]
# ['sir mix a lot', 'baby got back']
# ['sister hazel', 'all for you']
# ['sister sledge', 'we are family']
# ['sixpence none the richer', 'kiss me']
# ['skid row', 'i remember you']
# ['SLY & THE FAMILY STONE', 'dance to the music']
# ['SLY & THE FAMILY STONE', 'everyday people']
# ['SLY & THE FAMILY STONE', 'hot fun in the summertime']
# ['smashmouth', 'all star']
# ['SMASHMOUTH', 'walkin on the sun']
# ['soft cell', 'tainted love']
# ['sonny and cher', 'i got you babe']
# ['sons of the desert', "i'll take whatever comes first"]
# ['soul decision', 'faded']
# ['spacehog', 'in the meantime']
# ['spice girls', 'wannabe']
# ['spin doctors', "little miss can't be wrong"]
# ['SPIN DOCTORS', 'two princes']
# ['steel magnolia', "keep on lovin' you"]
# ['steelheart', 'we all die young']
# ['steppenwolf', 'BORN TO BE WILD']
# ['steve miller band', 'THE JOKER']
# ['steve perry', 'foolish heart']
# ['steven curtis chapman', 'i believe in you']
# ['stevie nicks / tom petty', "STOP DRAGGIN' MY HEART AROUND"]
# ['stevie ray vaughn', 'CROSSFIRE']
# ['STEVIE RAY VAUGHN', 'pride and joy']
# ['stevie wonder', 'do i do']
# ['STEVIE WONDER', 'i wish']
# ['STEVIE WONDER', "isn't she lovely"]
# ['STEVIE WONDER', 'sir duke']
# ['STEVIE WONDER', 'sunshine of my life']
# ['STEVIE WONDER', 'superstition']
# ['Sting', 'if i ever lose my faith in you']
# ['stone temple pilots', 'plush']
# ['styx', 'TOO MUCH TIME ON MY HANDS']
# ['sublime', 'SANTERIA']
# ['sugar ray', 'EVERY MORNING']
# ['SUGAR RAY', 'SOMEDAY']
# ['SUGAR RAY', "WHEN IT'S OVER"]
# ['sugarland', 'STUCK LIKE GLUE']
# ['survivor', 'EYE OF THE TIGER']
# ['susan tedeschi', 'HURT SO BAD']
# ['sweet', 'THE BALLROOM BLITZ']
# ['taio cruz', 'BREAK YOUR HEART']
# ['taio cruz', 'DYNAMITE']
# ['tal bachman', "SHE'S SO HIGH"]
# ['tammy wynette', 'STAND BY YOUR MAN']
# ['taylor swift', 'EYES OPEN']
# ['TAYLOR SWIFT', 'I KNEW YOU WERE TROUBLE']
# ['TAYLOR SWIFT', 'LAST CHRISTMAS']
# ['TAYLOR SWIFT', 'SHAKE IT OFF']
# ['tears for fears', 'EVERYBODY WANTS TO RULE THE WORLD']
# ['TEARS FOR FEARS', 'SHOUT']
# ['the 1975', 'CHOCOLATE']
# ["the 8-52's", 'LOVE SHACK']
# ['the band perry', 'DONE']
# ['the bangles', 'WALK LIKE AN EGYPTIAN']
# ['THE BEATLES', '8 DAYS A WEEK']
# ['THE BEATLES', 'EIGHT DAYS A WEEK']
# ['THE BEATLES', 'HELP']
# ['the black crows', 'JEALOUS AGAIN']
# ['the blues brothers', 'EVERYBODY NEEDS SOMEBODY TO LOVE']
# ['THE BLUES BROTHERS', 'SOUL MAN']
# ['the buggles', 'VIDEO KILLED THE RADIO STAR']
# ['the cardigans', 'LOVE FOOL']
# ['the cars', 'JUST WHAT I NEEDED']
# ['THE CARS', 'SHAKE IT UP']
# ['THE CARS', 'YOU MIGHT THINK']
# ['the chainsmokers', 'CLOSER']
# ['the clash', 'ROCK THE CASBAH']
# ['the cranberries', 'DREAMS']
# ['the cure', 'JUST LIKE HEAVEN']
# ['the darkness', 'I BELIEVE IN A THING CALLED LOVE']
# ['the dazz band', 'LET IT WHIP']
# ['the doobie brothers', 'LISTEN TO THE MUSIC']
# ['THE DOOBIE BROTHERS', 'WHAT A FOOL BELIEVES']
# ['the drifters', 'THIS MAGIC MOMENT']
# ['THE DRIFTERS', 'UNDER THE BOARDWALK']
# ['the fix', 'ONE THING LEADS TO ANOTHER']
# ['the fugees', 'KILLING ME SOFTLY']
# ['the gap band', 'YOU DROPPED THE BOMB ON ME']
# ["the go go's", 'OUR LIPS ARE SEALED']
# ['the greatest showman', 'THE GREATEST SHOW']
# ['the greg kihn band', 'JEOPARDY']
# ['the human league', "DON'T YOU WANT ME BABY"]
# ['the isley brothers', 'SHOUT']
# ['the killers', 'MR. BRIGHTSIDE']
# ['the knack', 'MY SHARONA']
# ['the lonely island', 'DICK IN A BOX']
# ['the madden brothers', 'WE ARE DONE']
# ['the mamas and papas', 'CALIFORNIA DREAMIN']
# ['the mavericks', 'CRYING SHAME']
# ['THE MAVERICKS', 'OH WHAT A THRILL']
# ['the offspring', 'ORIGINAL PRANKSTER']
# ['the outfield', 'YOUR LOVE']
# ['the police', 'EVERY BREATH YOU TAKE']
# ['THE POLICE', 'EVERY LITTLE THING SHE DOES IS MAGIC']
# ['THE POLICE', 'ROXANNE']
# ['THE POLICE', 'SYNCHRONICITY II']
# ['THE POLICE', 'WRAPPED AROUND YOUR FINGER']
# ['The pretenders', 'BRASS IN POCKET']
# ['the righteous brothers', 'UNCHAINED MELODY']
# ['the rembrandts', "I'LL BE THERE FOR YOU"]
# ['the romantics', 'TALKIN IN YOUR SLEEP']
# ['THE ROMANTICS', 'WHAT I LIKE ABOUT YOU']
# ['the s.o.s. band', 'JUST BE GOOD TO ME']
# ['the scorpions', 'ROCK YOU LIKE A HURRICANE']
# ['the script', 'BREAKEVEN (FALLING TO PIECES)']
# ['the smashing pumpkins', '1979']
# ['the spinners', "COULD IT BE I'M FALLING IN LOVE"]
# ['the supremes', 'COME SEE ABOUT ME']
# ['THE SUPREMES', "YOU CAN'T HURRY LOVE"]
# ['the temptations', 'MY GIRL']
# ['the trammps', 'Disco inferno']
# ['the tubes', "SHE'S A BEAUTY"]
# ['the vapors', "I THINK I'M TURNING JAPANESE"]
# ['the waitresses', 'christmas wrapping']
# ['the wallflowers', 'ONE HEADLIGHT']
# ['the wanted', 'GLAD YOU CAME']
# ['the weeknd', "CAN'T FEEL MY FACE"]
# ['THE WEEKND', 'I FEEL IT COMING']
# ['the whispers', 'ROCK STEADY']
# ['the white stripes', 'SEVEN NATION ARMY']
# ['the who', 'PINBALL WIZARD']
# ['the who', 'SUMMERTIME BLUES']
# ['the wonders', 'DANCE WITH ME TONIGHT']
# ['the zutons', 'VALERIE']
# ['third eye blind', 'NEVER LET YOU GO']
# ['THIRD EYE BLIND', 'SEMI-CHARMED LIFE']
# ['thomas dolby', 'SHE BLINDED ME WITH SCIENCE']
# ['thomas rhett', 'DIE A HAPPY MAN']
# ['THOMAS RHETT FEAT. MAREN MORRIS', 'CRAVING YOU']
# ['TIM MCGRAW', 'HUMBLE & KIND']
# ['TIM MCGRAW', 'INDIAN OUTLAW']
# ['TIM MCGRAW', 'JUST TO SEE YOU SMILE']
# ['TIM MCGRAW', 'MY LITTLE GIRL']
# ['TIM MCGRAW', 'SOMETHING LIKE THAT']
# ['TIMBALAND/KERI HILSON', 'THE WAY I ARE']
# ['TINA TURNER', 'A FOOL IN LOVE']
# ['TINA TURNER', 'LAND OF 1000 DANCES']
# ['TINA TURNER', 'PRIVATE DANCER']
# ['TINA TURNER', 'PROUD MARY']
# ['TINA TURNER', 'SIMPLY THE BEST']
# ['TINA TURNER', "WHAT'S LOVE GOT TO DO WITH IT"]
# ['TINA TURNER / BRYAN ADAMS', "IT'S ONLY LOVE"]
# ['TLC', 'NO SCRUBS']
# ['TLC', 'UNPRETTY']
# ['TLC', 'WATERFALLS']
# ['TOAD THE WET SPROCKET', 'ALL I WANT']
# ['toadies', 'TYLER']
# ['toby keith', 'RED SOLO CUP']
# ['tom cochrane', 'LIFE IS A HIGHWAY']
# ['tom jones', 'SEX BOMB']
# ['tom petty', 'last dance with mary jane']
# ['Tommy tutones', '867-5309 / JENNY']
# ['tone loc', 'WILD THING']
# ['tonic', 'IF YOU COULD ONLY SEE']
# ['tonic', 'YOU WANTED MORE']
# ['tony basil', 'HEY MICKEY']
# ["tony toni tone'", 'NO LOOT']
# ['tori kelly', 'NOBODY LOVE']
# ['toto', 'AFRICA']
# ['TOTO', 'HOLD THE LINE']
# ['TOTO', 'ROSANNA']
# ['tracy chapman', 'GIVE ME ONE REASON']
# ['train', 'DROPS OF JUPITER']
# ['TRAIN', 'HEY SOUL SISTER']
# ['TRAIN', 'MARRY ME']
# ['trey songs', 'BOTTOMS UP']
# ['trisha yearwood', 'YOU SAY YOU WILL']
# ['ty herndon', 'LIVIN IN A MOMENT']
# ['u2', 'BEAUTIFUL DAY']
# ['u2', "I STILL HAVEN'T FOUND WHAT IM LOOKING FOR"]
# ['uncle kracker', 'DRIFT AWAY']
# ['usher', 'DJ GOT US FALLIN IN LOVE AGAIN']
# ['usher / david guetta', 'WITHOUT YOU']
# ['v.i.c.', 'WOBBLE']
# ['van halen', 'DANCE THE NIGHT AWAY']
# ['VAN HALEN', 'FEEL YOUR LOVE TONIGHT']
# ['VAN HALEN', 'HOT FOR TEACHER']
# ['VAN HALEN', 'JUMP']
# ['VAN HALEN', 'PANAMA']
# ['VAN HALEN', 'RIGHT NOW']
# ['VAN HALEN', "RUNNIN' WITH THE DEVIL"]
# ['VAN HALEN', 'YOU REALLY GOT ME']
# ['van morrison', 'BROWN EYED GIRL']
# ['VAN MORRISON', 'SOMEONE LIKE YOU']
# ['vanessa carlton', 'A THOUSAND MILES']
# ['vanilla ice', 'ICE ICE BABY']
# ['vanity 6', 'NASTY GIRL']
# ['vengaboys', 'WE LIKE TO PARTY']
# ['vertical horizon', 'EVERYTHING YOU WANT']
# ['village people', 'MACHO MAN']
# ['VILLAGE PEOPLE', 'YMCA']
# ['vince gill', 'LIZA JANE']
# ['VIOLENT FEMMES', 'blister in the sun']
# ['walk the moon', 'shut up and dance']
# ['wang chung', 'everybody have fun tonight']
# ['waylon jennings', 'LUCKENBACh, TEXAS (BACK TO THE BASICS OF LOVE)']
# ['wayne newton', 'summer wind']
# ['wayne toups', 'Take my hand']
# ['weezer', 'island in the sun']
# ['wham', 'Last christmas']
# ['WHAM', 'wake me up before you go go']
# ['whitesnake', 'here I go again']
# ['WHITESNAKE', 'is this love']
# ['WHITESNAKE', 'still of the night']
# ['WHITNEY HOUSTON', 'how will i Know']
# ['WHITNEY HOUSTON', 'i have nothing']
# ['WHITNEY HOUSTON', 'i wanna dance with somebody']
# ['WHITNEY HOUSTON', 'i will always love you']
# ['WHITNEY HOUSTON', 'queen of the night']
# ['wild cherry', 'play that funky music']
# ['will smith', "gettin' jiggy with it"]
# ['WILL SMITH', 'miami']
# ['wilson pickett', 'land of 1000 dances']
# ['WILSON PICKETT', 'mustang sally']
# ['WRECKX-N-EFFECT', 'rump shaker']
# ['yes', 'owner of a lonely heart']
# ['young mc', 'bust a move']
# ['zac brown band', 'chicken fried']
# ['ZAC BROWN BAND', 'keep me in mind']
# ['ZAC BROWN BAND', 'overnight']
# ['zz top', 'tush']
